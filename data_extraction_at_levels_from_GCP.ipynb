# %% [markdown]
# <a href="https://colab.research.google.com/github/vaguiar/camelyon_dl_2019/blob/data-exploration/data_extraction_at_levels_from_GCP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install the OpenSlide C library and Python bindings
# !apt-get install openslide-tools
# !pip install openslide-python
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libopenslide0
# Suggested packages:
#   libtiff-tools
# The following NEW packages will be installed:
#   libopenslide0 openslide-tools
# 0 upgraded, 2 newly installed, 0 to remove and 16 not upgraded.
# Need to get 92.5 kB of archives.
# After this operation, 268 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenslide0 amd64 3.4.1+dfsg-2 [79.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 openslide-tools amd64 3.4.1+dfsg-2 [12.7 kB]
# Fetched 92.5 kB in 1s (178 kB/s)
# Selecting previously unselected package libopenslide0.
# (Reading database ... 130811 files and directories currently installed.)
# Preparing to unpack .../libopenslide0_3.4.1+dfsg-2_amd64.deb ...
# Unpacking libopenslide0 (3.4.1+dfsg-2) ...
# Selecting previously unselected package openslide-tools.
# Preparing to unpack .../openslide-tools_3.4.1+dfsg-2_amd64.deb ...
# Unpacking openslide-tools (3.4.1+dfsg-2) ...
# Setting up libopenslide0 (3.4.1+dfsg-2) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Setting up openslide-tools (3.4.1+dfsg-2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Collecting openslide-python
#   Downloading https://files.pythonhosted.org/packages/26/5a/5b0adeabce81f018a9e4ffe9a419536064bc95c1b12194aff9b7e48f91f7/openslide-python-1.1.1.tar.gz (312kB)
#      |████████████████████████████████| 317kB 2.9MB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from openslide-python) (4.3.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow->openslide-python) (0.46)
# Building wheels for collected packages: openslide-python
#   Building wheel for openslide-python (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/56/44/7e/16c9fc72cfbf1bffe48676b6835843d21abcc56566e958e7d6
# Successfully built openslide-python
# Installing collected packages: openslide-python
# Successfully installed openslide-python-1.1.1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from openslide import open_slide, __library_version__ as openslide_version
import os
import io
from PIL import Image
from skimage.color import rgb2gray

# %% [markdown]
# ### Setting up Google Cloud Platform

# %%
from google.colab import auth
auth.authenticate_user()

# %%
GCP_PROJECT_ID = 'triple-voyage-239123'
GCP_BUCKET_NAME = 'vaa2114_dl_2019'

# %%
# !gcloud config set project {GCP_PROJECT_ID}
# Out:
# Updated property [core/project].

# %%
from google.cloud import storage

CLIENT = storage.Client(project=GCP_PROJECT_ID)
BUCKET_ = CLIENT.bucket(GCP_BUCKET_NAME)

def save_to_gcp(gcp_file_name, file_buf):
  
  blob = BUCKET_.blob(gcp_file_name)
  
  # upload buffer contents to gcs
  blob.upload_from_string(
      file_buf.getvalue(),
      content_type='image/png')
  
  # gcs url to uploaded matplotlib image
  url = blob.public_url

# %% [markdown]
# ### Read slides from Google Cloud Platform bucket

# %%
BASE_DIR = 'gs://vaa2114_dl_2019/slides'

images = !gsutil ls {BASE_DIR} | cut -d / -f 5

masks = [s for s in images if "_mask.tif" in s]
masks.sort()
slides = list(set(images).difference(set(masks)))
slides.sort()

print(masks)
print(slides)

masks_slides = zip(masks, slides)
masks_slides  = list(masks_slides)

print(masks_slides)
# Out:
# ['tumor_001_mask.tif', 'tumor_002_mask.tif', 'tumor_005_mask.tif', 'tumor_012_mask.tif', 'tumor_016_mask.tif', 'tumor_019_mask.tif', 'tumor_023_mask.tif', 'tumor_031_mask.tif', 'tumor_035_mask.tif', 'tumor_057_mask.tif', 'tumor_059_mask.tif', 'tumor_075_mask.tif', 'tumor_081_mask.tif', 'tumor_084_mask.tif', 'tumor_091_mask.tif', 'tumor_094_mask.tif', 'tumor_096_mask.tif', 'tumor_101_mask.tif', 'tumor_110_mask.tif']
# ['tumor_001.tif', 'tumor_002.tif', 'tumor_005.tif', 'tumor_012.tif', 'tumor_016.tif', 'tumor_019.tif', 'tumor_023.tif', 'tumor_031.tif', 'tumor_035.tif', 'tumor_057.tif', 'tumor_059.tif', 'tumor_096.tif']
# [('tumor_001_mask.tif', 'tumor_001.tif'), ('tumor_002_mask.tif', 'tumor_002.tif'), ('tumor_005_mask.tif', 'tumor_005.tif'), ('tumor_012_mask.tif', 'tumor_012.tif'), ('tumor_016_mask.tif', 'tumor_016.tif'), ('tumor_019_mask.tif', 'tumor_019.tif'), ('tumor_023_mask.tif', 'tumor_023.tif'), ('tumor_031_mask.tif', 'tumor_031.tif'), ('tumor_035_mask.tif', 'tumor_035.tif'), ('tumor_057_mask.tif', 'tumor_057.tif'), ('tumor_059_mask.tif', 'tumor_059.tif'), ('tumor_075_mask.tif', 'tumor_096.tif')]

# %%
import random

def getSlide_Mask(slide_file, tumor_mask_file):

  slide_path = os.path.join(BASE_DIR, slide_file)
  tumor_mask_path = os.path.join(BASE_DIR, tumor_mask_file)


  slide = open_slide(slide_path)
  tumor_mask = open_slide(tumor_mask_path)
  
  # some slides have more than 8 levels, since we will only use the first 8 levels 
  # we will only assert that the first 8 levels have the appropriate dimensions 
  for i in range(8):  
      assert tumor_mask.level_dimensions[i][0] == slide.level_dimensions[i][0]
      assert tumor_mask.level_dimensions[i][1] == slide.level_dimensions[i][1]

  # Verify downsampling works as expected
  width, height = slide.level_dimensions[7]
  assert width * slide.level_downsamples[7] == slide.level_dimensions[0][0]
  assert height * slide.level_downsamples[7] == slide.level_dimensions[0][1]
  
  return slide, tumor_mask

def read_slide(slide, x, y, level, width, height, as_float=False):
    im = slide.read_region((x,y), level, (width, height))
    im = im.convert('RGB') # drop the alpha channel
    if as_float:
        im = np.asarray(im, dtype=np.float32)
    else:
        im = np.asarray(im)
    assert im.shape == (height, width, 3)
    return im
  
  
def find_tissue_pixels(image, intensity=0.8):
    im_gray = rgb2gray(image)
    assert im_gray.shape == (image.shape[0], image.shape[1])
    indices = np.where(im_gray <= intensity)
    return zip(indices[0], indices[1])

  

  

def getTraining_Data(level, slide, 
                     tumor_mask, 
                     slide_window, 
                     tumor_path, 
                     non_tumor_path,
                     slide_file,
                     is_sampling=False,
                     min_x = 0, 
                     min_y = 0, 
                     cancer_thres = 0, 
                     tissue_thres = .2):
  '''
  use a sliding window filter of size (slide_height, slide_width) 
  save in cancer folder if more than 30% of pixels are cancerous 
  save in non_cancer folder if more than 10% of the slide is pixels 
  '''
  
 
  down_sample = int(slide.level_downsamples[level])
  pixel_width = int(down_sample*slide.level_dimensions[level][0])
  pixel_height = int(down_sample*slide.level_dimensions[level][1])
  
  # loop through image pixels 
  for x in range(min_x*down_sample, pixel_width, slide_window*down_sample):
    for y in range(min_y*down_sample, pixel_height, slide_window*down_sample):

      # calculate slide width and slide height if image size starting at 
      # (x,y) is less than (slide_width, slide_height)
      slide_width_2 =  min(slide_window , slide.level_dimensions[level][0] - x/down_sample)
      slide_height_2 = min(slide_window , slide.level_dimensions[level][1] - y/down_sample)

      slide_image = read_slide(slide, 
                           x=x, 
                           y=y, 
                           level=level, 
                           width= int(slide_width_2) , 
                           height= int(slide_height_2) )
      
      
      # find % of tissues on slide_image
      tissue_pixels = find_tissue_pixels(slide_image)
      num_pixels = len(list(tissue_pixels))
      pcnt_tissue = num_pixels/ float(slide_image.shape[0] * slide_image.shape[0])


      mask_image = read_slide(tumor_mask,
                              x=x, 
                              y=y, 
                              level=level, 
                              width= int(slide_width_2) , 
                              height= int(slide_height_2) )

      mask_image = mask_image[:,:,0]

      # get % of cancer cells in mask 
      num_cancer =  np.sum(mask_image)
      
      # if the image is not a square do not save as it is likely the end of the slide 
      # this improves efficieny 
      if slide_width_2 != slide_height_2:
        save_dir = 'DISCARD'
      
      # if % cancer > cancer_thres then save to cancer directory
      elif num_cancer  > cancer_thres:
        save_dir = tumor_path 
        
      # if non-cancerous and percent of tissues is greater than tissue threshold
      # save to the non-cancerous directory
      elif ((num_cancer <=  cancer_thres) & (pcnt_tissue >= tissue_thres)):
        if (is_sampling and random.randint(0,1)):
            save_dir = 'DISCARD' 
            name = save_dir + "/" + "level_" + str(level) + "_" + str(x) + "_" + str(y)+ "_" + str(slide_window) + "_" + slide_file
            print("Discard Non tumor image: ", name)     
        else: 
          save_dir = non_tumor_path
        
      else:
        save_dir = 'DISCARD' 
   
      
      # save images if not meant to be discarded.       
      if save_dir == 'DISCARD':      
        pass 
      
      else: 
        name = save_dir + "/" + "level_" + str(level) + "_" + str(x) + "_" + str(y)+ "_" + str(slide_window) + "_" + slide_file

        print("# tumor pxls:{}, % tumor pxls:{}, file_name:{}".format(num_cancer , pcnt_tissue, name))
        plt.figure(figsize=(10,10), dpi=100)
        plt.imshow(slide_image)
        
        buf = io.BytesIO()
        plt.savefig(buf, format='png')
        save_to_gcp(name, buf)
        
        buf.close()
        
        plt.close()

# %%
def extract_data_by_level(level, 
                          masks_slides,
                          slide_window,
                          is_sampling):

  
  GCP_TRAIN_TUMOR_FOLDER = "train/level{}/tumor".format(level)
  GCP_TRAIN_NON_TUMOR_FOLDER = "train/level{}/non_tumor".format(level)
  
  GCP_VAL_TUMOR_FOLDER = "validate/level{}/tumor".format(level)
  GCP_VAL_NON_TUMOR_FOLDER = "validate/level{}/non_tumor".format(level)
  
  GCP_TEST_TUMOR_FOLDER = "test/level{}/tumor".format(level)
  GCP_TEST_NON_TUMOR_FOLDER = "test/level{}/non_tumor".format(level)

  print("GCP Train Data Paths:")
  print(GCP_TRAIN_TUMOR_FOLDER)
  print(GCP_TRAIN_NON_TUMOR_FOLDER)
  
  print("\nGCP Validate Data Paths:")
  print(GCP_VAL_TUMOR_FOLDER)
  print(GCP_VAL_NON_TUMOR_FOLDER)
  
  print("\nGCP Test Data Paths:")
  print(GCP_TEST_TUMOR_FOLDER)
  print(GCP_TEST_NON_TUMOR_FOLDER)
  
  for i in range(len(masks_slides)):
  
    print("\nExtracting Data w/ level={}, window_size={}, image_number={}".format(level, slide_window, i))
    slide_masks = masks_slides[i]
    slide_file = slide_masks[1]
    tumor_mask_file =slide_masks[0]
    slide, tumor_mask = getSlide_Mask(slide_file, tumor_mask_file)

    if (i+1)%5 == 0:
      TUMOR_FOLDER = GCP_VAL_TUMOR_FOLDER
      NON_TUMOR_FOLDER = GCP_VAL_NON_TUMOR_FOLDER
      is_sampling = False      # Turn off sampling for Validation set
    elif (i+1)%9 == 0:
      TUMOR_FOLDER = GCP_TEST_TUMOR_FOLDER
      NON_TUMOR_FOLDER = GCP_TEST_NON_TUMOR_FOLDER
      is_sampling = False      # Turn off sampling for Test set
    else:
      TUMOR_FOLDER = GCP_TRAIN_TUMOR_FOLDER
      NON_TUMOR_FOLDER = GCP_TRAIN_NON_TUMOR_FOLDER

    getTraining_Data(level, 
                     slide, 
                     tumor_mask, 
                     slide_window, 
                     TUMOR_FOLDER, 
                     NON_TUMOR_FOLDER, 
                     slide_file,
                     is_sampling)

# %% [markdown]
# ## Running data extractor by level
#
# The new image file stored has the following naming convention:
#
# ```
# level_<level_num>_<window_x_coord>_<window_y_coord>_<window_size>_<filename>
# ```
#
# **Sliding Window Size Calculations**
#
# | Level  |   Zoom Factor |  Window Size |
# |---|---|---|
# |  7 |  1x |  200  |
# |  6 |  2x |   |
# |   5|  4x |  400 |
# |   4|  8x |   |
# |   3|  16x | 800 |
# |   2| 32x |   |
# |   1|  64x |   3200|
# |   0|  128x |   |

# %% [markdown]
# ### Running for level 7 with window size 200

# %%
LEVEL = 7
SLIDING_WINDOW = 200
IS_SAMPLING = False

extract_data_by_level(LEVEL, 
                      masks_slides,
                      SLIDING_WINDOW,
                      IS_SAMPLING)
# Out:
# GCP Train Data Paths:
# train/level7/tumor
# train/level7/non_tumor
#
# GCP Validate Data Paths:
# validate/level7/tumor
# validate/level7/non_tumor
#
# GCP Test Data Paths:
# test/level7/tumor
# test/level7/non_tumor
#
# Extracting Data w/ level=7, window_size=250, image_number=0
# # tumor pxls:0, % tumor pxls:0.418928, file_name:train/level7/non_tumor/level_7_0_64000_250_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.361936, file_name:train/level7/non_tumor/level_7_32000_64000_250_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.245616, file_name:train/level7/non_tumor/level_7_32000_96000_250_tumor_001.tif
# # tumor pxls:575, % tumor pxls:0.103808, file_name:train/level7/tumor/level_7_64000_96000_250_tumor_001.tif
# # tumor pxls:122, % tumor pxls:0.080912, file_name:train/level7/tumor/level_7_64000_128000_250_tumor_001.tif
#
# Extracting Data w/ level=7, window_size=250, image_number=1
# # tumor pxls:61, % tumor pxls:0.258992, file_name:train/level7/tumor/level_7_32000_96000_250_tumor_002.tif
#
# Extracting Data w/ level=7, window_size=250, image_number=2
# # tumor pxls:147, % tumor pxls:0.398176, file_name:train/level7/tumor/level_7_32000_128000_250_tumor_005.tif
# # tumor pxls:0, % tumor pxls:0.20928, file_name:train/level7/non_tumor/level_7_32000_160000_250_tumor_005.tif
#
# Extracting Data w/ level=7, window_size=250, image_number=3
# # tumor pxls:72, % tumor pxls:0.284128, file_name:train/level7/tumor/level_7_32000_64000_250_tumor_012.tif
# # tumor pxls:0, % tumor pxls:0.465344, file_name:train/level7/non_tumor/level_7_32000_96000_250_tumor_012.tif
#
# Extracting Data w/ level=7, window_size=250, image_number=4
# # tumor pxls:882, % tumor pxls:0.054688, file_name:validate/level7/tumor/level_7_0_160000_250_tumor_016.tif
# # tumor pxls:0, % tumor pxls:0.2228, file_name:validate/level7/non_tumor/level_7_32000_96000_250_tumor_016.tif
# # tumor pxls:3394, % tumor pxls:0.538736, file_name:validate/level7/tumor/level_7_32000_128000_250_tumor_016.tif
# # tumor pxls:5535, % tumor pxls:0.115328, file_name:validate/level7/tumor/level_7_32000_160000_250_tumor_016.tif
#
# Extracting Data w/ level=7, window_size=250, image_number=5
# # tumor pxls:204, % tumor pxls:0.167648, file_name:train/level7/tumor/level_7_32000_64000_250_tumor_019.tif
#
# Extracting Data w/ level=7, window_size=250, image_number=6
# # tumor pxls:19, % tumor pxls:0.137232, file_name:train/level7/tumor/level_7_32000_96000_250_tumor_023.tif
# # tumor pxls:97, % tumor pxls:0.289504, file_name:train/level7/tumor/level_7_32000_128000_250_tumor_023.tif
# # tumor pxls:4, % tumor pxls:0.252944, file_name:train/level7/tumor/level_7_64000_128000_250_tumor_023.tif
#
# Extracting Data w/ level=7, window_size=250, image_number=7
# # tumor pxls:3523, % tumor pxls:0.30152, file_name:train/level7/tumor/level_7_32000_128000_250_tumor_031.tif
# # tumor pxls:4079, % tumor pxls:0.173824, file_name:train/level7/tumor/level_7_32000_160000_250_tumor_031.tif
#
# Extracting Data w/ level=7, window_size=250, image_number=8
# # tumor pxls:5, % tumor pxls:0.269872, file_name:test/level7/tumor/level_7_32000_64000_250_tumor_035.tif
# # tumor pxls:7, % tumor pxls:0.217472, file_name:test/level7/tumor/level_7_32000_96000_250_tumor_035.tif
#
# Extracting Data w/ level=7, window_size=250, image_number=9
# # tumor pxls:76, % tumor pxls:0.169904, file_name:validate/level7/tumor/level_7_0_128000_250_tumor_057.tif
#
# Extracting Data w/ level=7, window_size=250, image_number=10
# # tumor pxls:16, % tumor pxls:0.241504, file_name:train/level7/tumor/level_7_32000_96000_250_tumor_059.tif
# # tumor pxls:0, % tumor pxls:0.345264, file_name:train/level7/non_tumor/level_7_32000_128000_250_tumor_059.tif
#
# Extracting Data w/ level=7, window_size=250, image_number=11
# # tumor pxls:1672, % tumor pxls:0.089984, file_name:train/level7/tumor/level_7_0_96000_250_tumor_064.tif
# # tumor pxls:475, % tumor pxls:0.227232, file_name:train/level7/tumor/level_7_0_128000_250_tumor_064.tif
# # tumor pxls:3038, % tumor pxls:0.09344, file_name:train/level7/tumor/level_7_0_160000_250_tumor_064.tif
# # tumor pxls:2974, % tumor pxls:0.364624, file_name:train/level7/tumor/level_7_64000_128000_250_tumor_064.tif
#
# Extracting Data w/ level=7, window_size=250, image_number=12
# # tumor pxls:639, % tumor pxls:0.313696, file_name:train/level7/tumor/level_7_0_32000_250_tumor_075.tif
# # tumor pxls:472, % tumor pxls:0.14032, file_name:train/level7/tumor/level_7_32000_0_250_tumor_075.tif
# # tumor pxls:1813, % tumor pxls:0.121712, file_name:train/level7/tumor/level_7_32000_32000_250_tumor_075.tif
#
# Extracting Data w/ level=7, window_size=250, image_number=13
# # tumor pxls:9990, % tumor pxls:0.497408, file_name:train/level7/tumor/level_7_0_32000_250_tumor_078.tif
# # tumor pxls:2694, % tumor pxls:0.312352, file_name:train/level7/tumor/level_7_0_64000_250_tumor_078.tif
# # tumor pxls:4667, % tumor pxls:0.427104, file_name:train/level7/tumor/level_7_32000_0_250_tumor_078.tif
# # tumor pxls:4622, % tumor pxls:0.413712, file_name:train/level7/tumor/level_7_32000_32000_250_tumor_078.tif
# # tumor pxls:22773, % tumor pxls:0.64968, file_name:train/level7/tumor/level_7_32000_64000_250_tumor_078.tif
#
# Extracting Data w/ level=7, window_size=250, image_number=14
# # tumor pxls:0, % tumor pxls:0.271184, file_name:validate/level7/non_tumor/level_7_0_0_250_tumor_081.tif
# # tumor pxls:0, % tumor pxls:0.222288, file_name:validate/level7/non_tumor/level_7_0_32000_250_tumor_081.tif
# # tumor pxls:30, % tumor pxls:0.310448, file_name:validate/level7/tumor/level_7_32000_32000_250_tumor_081.tif
#
# Extracting Data w/ level=7, window_size=250, image_number=15
# # tumor pxls:1594, % tumor pxls:0.451248, file_name:train/level7/tumor/level_7_0_32000_250_tumor_084.tif
# # tumor pxls:367, % tumor pxls:0.341152, file_name:train/level7/tumor/level_7_32000_0_250_tumor_084.tif
# # tumor pxls:0, % tumor pxls:0.25352, file_name:train/level7/non_tumor/level_7_32000_32000_250_tumor_084.tif
#
# Extracting Data w/ level=7, window_size=250, image_number=16
# # tumor pxls:0, % tumor pxls:0.282032, file_name:train/level7/non_tumor/level_7_0_0_250_tumor_091.tif
#
# Extracting Data w/ level=7, window_size=250, image_number=17
# # tumor pxls:0, % tumor pxls:0.223936, file_name:test/level7/non_tumor/level_7_0_0_250_tumor_094.tif
# # tumor pxls:2, % tumor pxls:0.404032, file_name:test/level7/tumor/level_7_32000_32000_250_tumor_094.tif
# # tumor pxls:0, % tumor pxls:0.41776, file_name:test/level7/non_tumor/level_7_32000_64000_250_tumor_094.tif
# # tumor pxls:3121, % tumor pxls:0.310656, file_name:test/level7/tumor/level_7_64000_0_250_tumor_094.tif
# # tumor pxls:710, % tumor pxls:0.286928, file_name:test/level7/tumor/level_7_64000_32000_250_tumor_094.tif
#
# Extracting Data w/ level=7, window_size=250, image_number=18
# # tumor pxls:0, % tumor pxls:0.204736, file_name:train/level7/non_tumor/level_7_0_0_250_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.255728, file_name:train/level7/non_tumor/level_7_0_32000_250_tumor_096.tif
# # tumor pxls:792, % tumor pxls:0.268064, file_name:train/level7/tumor/level_7_32000_0_250_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.208272, file_name:train/level7/non_tumor/level_7_32000_32000_250_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.251376, file_name:train/level7/non_tumor/level_7_64000_32000_250_tumor_096.tif
# # tumor pxls:618, % tumor pxls:0.272928, file_name:train/level7/tumor/level_7_96000_0_250_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.280048, file_name:train/level7/non_tumor/level_7_96000_32000_250_tumor_096.tif
#
# Extracting Data w/ level=7, window_size=250, image_number=19
# # tumor pxls:2491, % tumor pxls:0.318384, file_name:validate/level7/tumor/level_7_0_0_250_tumor_101.tif
# # tumor pxls:3308, % tumor pxls:0.39848, file_name:validate/level7/tumor/level_7_32000_0_250_tumor_101.tif
# # tumor pxls:114, % tumor pxls:0.30976, file_name:validate/level7/tumor/level_7_32000_32000_250_tumor_101.tif
# # tumor pxls:134, % tumor pxls:0.153008, file_name:validate/level7/tumor/level_7_64000_0_250_tumor_101.tif
# # tumor pxls:5597, % tumor pxls:0.53952, file_name:validate/level7/tumor/level_7_96000_0_250_tumor_101.tif
# # tumor pxls:112, % tumor pxls:0.4136, file_name:validate/level7/tumor/level_7_96000_32000_250_tumor_101.tif
#
# Extracting Data w/ level=7, window_size=250, image_number=20
# # tumor pxls:13478, % tumor pxls:0.254096, file_name:train/level7/tumor/level_7_0_0_250_tumor_110.tif
# # tumor pxls:12503, % tumor pxls:0.516256, file_name:train/level7/tumor/level_7_0_32000_250_tumor_110.tif
# # tumor pxls:28023, % tumor pxls:0.647744, file_name:train/level7/tumor/level_7_32000_0_250_tumor_110.tif
# # tumor pxls:10262, % tumor pxls:0.612192, file_name:train/level7/tumor/level_7_32000_32000_250_tumor_110.tif

# %% [markdown]
# ### Running for level 5 with window size 400

# %%
LEVEL = 5
SLIDING_WINDOW = 400
IS_SAMPLING = False

extract_data_by_level(LEVEL, 
                      masks_slides,
                      SLIDING_WINDOW,
                      IS_SAMPLING)
# Out:
# GCP Train Data Paths:
# train/level5/tumor
# train/level5/non_tumor
#
# GCP Validate Data Paths:
# validate/level5/tumor
# validate/level5/non_tumor
#
# GCP Test Data Paths:
# test/level5/tumor
# test/level5/non_tumor
#
# Extracting Data w/ level=5, window_size=400, image_number=0
# # tumor pxls:0, % tumor pxls:0.21549375, file_name:train/level5/non_tumor/level_5_0_115200_400_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.55414375, file_name:train/level5/non_tumor/level_5_0_128000_400_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.75815625, file_name:train/level5/non_tumor/level_5_12800_76800_400_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.52246875, file_name:train/level5/non_tumor/level_5_12800_89600_400_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.21566875, file_name:train/level5/non_tumor/level_5_12800_115200_400_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.6886875, file_name:train/level5/non_tumor/level_5_25600_64000_400_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.79566875, file_name:train/level5/non_tumor/level_5_25600_76800_400_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.34100625, file_name:train/level5/non_tumor/level_5_25600_89600_400_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.37899375, file_name:train/level5/non_tumor/level_5_38400_64000_400_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.6893875, file_name:train/level5/non_tumor/level_5_38400_76800_400_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.21631875, file_name:train/level5/non_tumor/level_5_38400_102400_400_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.229225, file_name:train/level5/non_tumor/level_5_38400_115200_400_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.20690625, file_name:train/level5/non_tumor/level_5_38400_128000_400_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.8324, file_name:train/level5/non_tumor/level_5_51200_115200_400_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.51595625, file_name:train/level5/non_tumor/level_5_51200_128000_400_tumor_001.tif
# # tumor pxls:9190, % tumor pxls:0.48211875, file_name:train/level5/tumor/level_5_64000_115200_400_tumor_001.tif
# # tumor pxls:1926, % tumor pxls:0.47998125, file_name:train/level5/tumor/level_5_64000_128000_400_tumor_001.tif
#
# Extracting Data w/ level=5, window_size=400, image_number=1
# # tumor pxls:0, % tumor pxls:0.39824375, file_name:train/level5/non_tumor/level_5_12800_102400_400_tumor_002.tif
# # tumor pxls:0, % tumor pxls:0.69958125, file_name:train/level5/non_tumor/level_5_25600_89600_400_tumor_002.tif
# # tumor pxls:0, % tumor pxls:0.33410625, file_name:train/level5/non_tumor/level_5_25600_102400_400_tumor_002.tif
# # tumor pxls:0, % tumor pxls:0.46593125, file_name:train/level5/non_tumor/level_5_38400_89600_400_tumor_002.tif
# # tumor pxls:938, % tumor pxls:0.479375, file_name:train/level5/tumor/level_5_38400_102400_400_tumor_002.tif
# # tumor pxls:0, % tumor pxls:0.632475, file_name:train/level5/non_tumor/level_5_38400_140800_400_tumor_002.tif
# # tumor pxls:0, % tumor pxls:0.22200625, file_name:train/level5/non_tumor/level_5_51200_115200_400_tumor_002.tif
# # tumor pxls:0, % tumor pxls:0.434125, file_name:train/level5/non_tumor/level_5_64000_115200_400_tumor_002.tif
#
# Extracting Data w/ level=5, window_size=400, image_number=2
# # tumor pxls:0, % tumor pxls:0.390475, file_name:train/level5/non_tumor/level_5_12800_166400_400_tumor_005.tif
# # tumor pxls:0, % tumor pxls:0.35240625, file_name:train/level5/non_tumor/level_5_25600_140800_400_tumor_005.tif
# # tumor pxls:0, % tumor pxls:0.3521375, file_name:train/level5/non_tumor/level_5_25600_153600_400_tumor_005.tif
# # tumor pxls:0, % tumor pxls:0.63183125, file_name:train/level5/non_tumor/level_5_25600_166400_400_tumor_005.tif
# # tumor pxls:0, % tumor pxls:0.69174375, file_name:train/level5/non_tumor/level_5_38400_140800_400_tumor_005.tif
# # tumor pxls:0, % tumor pxls:0.3187125, file_name:train/level5/non_tumor/level_5_38400_153600_400_tumor_005.tif
# # tumor pxls:0, % tumor pxls:0.6304125, file_name:train/level5/non_tumor/level_5_38400_166400_400_tumor_005.tif
# # tumor pxls:2323, % tumor pxls:0.3460125, file_name:train/level5/tumor/level_5_51200_128000_400_tumor_005.tif
# # tumor pxls:0, % tumor pxls:0.54314375, file_name:train/level5/non_tumor/level_5_51200_140800_400_tumor_005.tif
#
# Extracting Data w/ level=5, window_size=400, image_number=3
# # tumor pxls:0, % tumor pxls:0.49678125, file_name:train/level5/non_tumor/level_5_38400_51200_400_tumor_012.tif
# # tumor pxls:539, % tumor pxls:0.59878125, file_name:train/level5/tumor/level_5_38400_64000_400_tumor_012.tif
# # tumor pxls:576, % tumor pxls:0.0185375, file_name:train/level5/tumor/level_5_38400_76800_400_tumor_012.tif
# # tumor pxls:0, % tumor pxls:0.8739875, file_name:train/level5/non_tumor/level_5_38400_115200_400_tumor_012.tif
# # tumor pxls:0, % tumor pxls:0.38323125, file_name:train/level5/non_tumor/level_5_38400_128000_400_tumor_012.tif
# # tumor pxls:0, % tumor pxls:0.66301875, file_name:train/level5/non_tumor/level_5_51200_51200_400_tumor_012.tif
# # tumor pxls:0, % tumor pxls:0.552475, file_name:train/level5/non_tumor/level_5_51200_64000_400_tumor_012.tif
# # tumor pxls:0, % tumor pxls:0.7937125, file_name:train/level5/non_tumor/level_5_51200_89600_400_tumor_012.tif
# # tumor pxls:0, % tumor pxls:0.38611875, file_name:train/level5/non_tumor/level_5_51200_102400_400_tumor_012.tif
# # tumor pxls:0, % tumor pxls:0.98500625, file_name:train/level5/non_tumor/level_5_51200_115200_400_tumor_012.tif
# # tumor pxls:0, % tumor pxls:0.3709875, file_name:train/level5/non_tumor/level_5_51200_128000_400_tumor_012.tif
# # tumor pxls:0, % tumor pxls:0.28441875, file_name:train/level5/non_tumor/level_5_64000_51200_400_tumor_012.tif
# # tumor pxls:0, % tumor pxls:0.43750625, file_name:train/level5/non_tumor/level_5_64000_115200_400_tumor_012.tif
#
# Extracting Data w/ level=5, window_size=400, image_number=4
# # tumor pxls:0, % tumor pxls:0.287275, file_name:validate/level5/non_tumor/level_5_25600_128000_400_tumor_016.tif
# # tumor pxls:1286, % tumor pxls:0.50455, file_name:validate/level5/tumor/level_5_25600_140800_400_tumor_016.tif
# # tumor pxls:30543, % tumor pxls:0.930425, file_name:validate/level5/tumor/level_5_25600_153600_400_tumor_016.tif
# # tumor pxls:24815, % tumor pxls:0.16404375, file_name:validate/level5/tumor/level_5_25600_166400_400_tumor_016.tif
# # tumor pxls:0, % tumor pxls:0.57236875, file_name:validate/level5/non_tumor/level_5_38400_128000_400_tumor_016.tif
# # tumor pxls:30047, % tumor pxls:0.9365375, file_name:validate/level5/tumor/level_5_38400_140800_400_tumor_016.tif
# # tumor pxls:64141, % tumor pxls:0.7537125, file_name:validate/level5/tumor/level_5_38400_153600_400_tumor_016.tif
# # tumor pxls:6149, % tumor pxls:0.0421375, file_name:validate/level5/tumor/level_5_38400_166400_400_tumor_016.tif
# # tumor pxls:0, % tumor pxls:0.21356875, file_name:validate/level5/non_tumor/level_5_51200_89600_400_tumor_016.tif
# # tumor pxls:0, % tumor pxls:0.6005, file_name:validate/level5/non_tumor/level_5_51200_102400_400_tumor_016.tif
# # tumor pxls:0, % tumor pxls:0.23326875, file_name:validate/level5/non_tumor/level_5_51200_140800_400_tumor_016.tif
#
# Extracting Data w/ level=5, window_size=400, image_number=5
# # tumor pxls:1149, % tumor pxls:0.46571875, file_name:train/level5/tumor/level_5_51200_76800_400_tumor_019.tif
# # tumor pxls:2116, % tumor pxls:0.39908125, file_name:train/level5/tumor/level_5_51200_89600_400_tumor_019.tif
# # tumor pxls:0, % tumor pxls:0.31096875, file_name:train/level5/non_tumor/level_5_51200_140800_400_tumor_019.tif
# # tumor pxls:0, % tumor pxls:0.424025, file_name:train/level5/non_tumor/level_5_64000_76800_400_tumor_019.tif
# # tumor pxls:0, % tumor pxls:0.2541375, file_name:train/level5/non_tumor/level_5_64000_140800_400_tumor_019.tif
# # tumor pxls:0, % tumor pxls:0.432275, file_name:train/level5/non_tumor/level_5_64000_153600_400_tumor_019.tif
#
# Extracting Data w/ level=5, window_size=400, image_number=6
# # tumor pxls:0, % tumor pxls:0.53985625, file_name:train/level5/non_tumor/level_5_25600_115200_400_tumor_023.tif
# # tumor pxls:0, % tumor pxls:0.33829375, file_name:train/level5/non_tumor/level_5_25600_128000_400_tumor_023.tif
# # tumor pxls:0, % tumor pxls:0.41348125, file_name:train/level5/non_tumor/level_5_25600_140800_400_tumor_023.tif
# # tumor pxls:307, % tumor pxls:0.5268, file_name:train/level5/tumor/level_5_38400_115200_400_tumor_023.tif
# # tumor pxls:1616, % tumor pxls:0.7606125, file_name:train/level5/tumor/level_5_38400_128000_400_tumor_023.tif
# # tumor pxls:0, % tumor pxls:0.29330625, file_name:train/level5/non_tumor/level_5_38400_140800_400_tumor_023.tif
# # tumor pxls:0, % tumor pxls:0.5096, file_name:train/level5/non_tumor/level_5_64000_128000_400_tumor_023.tif
# # tumor pxls:0, % tumor pxls:0.40398125, file_name:train/level5/non_tumor/level_5_64000_140800_400_tumor_023.tif
# # tumor pxls:0, % tumor pxls:0.44428125, file_name:train/level5/non_tumor/level_5_64000_153600_400_tumor_023.tif
# # tumor pxls:79, % tumor pxls:0.26584375, file_name:train/level5/tumor/level_5_76800_140800_400_tumor_023.tif
#
# Extracting Data w/ level=5, window_size=400, image_number=7
# # tumor pxls:20, % tumor pxls:0.0023375, file_name:train/level5/tumor/level_5_38400_128000_400_tumor_031.tif
# # tumor pxls:11988, % tumor pxls:0.229575, file_name:train/level5/tumor/level_5_38400_140800_400_tumor_031.tif
# # tumor pxls:43516, % tumor pxls:0.4680375, file_name:train/level5/tumor/level_5_38400_153600_400_tumor_031.tif
# # tumor pxls:2734, % tumor pxls:0.07628125, file_name:train/level5/tumor/level_5_38400_166400_400_tumor_031.tif
# # tumor pxls:0, % tumor pxls:0.2361375, file_name:train/level5/non_tumor/level_5_51200_102400_400_tumor_031.tif
# # tumor pxls:20651, % tumor pxls:0.87944375, file_name:train/level5/tumor/level_5_51200_140800_400_tumor_031.tif
# # tumor pxls:23541, % tumor pxls:0.9140875, file_name:train/level5/tumor/level_5_51200_153600_400_tumor_031.tif
# # tumor pxls:19174, % tumor pxls:0.269125, file_name:train/level5/tumor/level_5_51200_166400_400_tumor_031.tif
#
# Extracting Data w/ level=5, window_size=400, image_number=8
# # tumor pxls:0, % tumor pxls:0.36605, file_name:test/level5/non_tumor/level_5_25600_64000_400_tumor_035.tif
# # tumor pxls:0, % tumor pxls:0.65844375, file_name:test/level5/non_tumor/level_5_25600_76800_400_tumor_035.tif
# # tumor pxls:0, % tumor pxls:0.768225, file_name:test/level5/non_tumor/level_5_25600_89600_400_tumor_035.tif
# # tumor pxls:0, % tumor pxls:0.5362875, file_name:test/level5/non_tumor/level_5_25600_102400_400_tumor_035.tif
# # tumor pxls:75, % tumor pxls:0.10948125, file_name:test/level5/tumor/level_5_38400_76800_400_tumor_035.tif
# # tumor pxls:93, % tumor pxls:0.28950625, file_name:test/level5/tumor/level_5_38400_89600_400_tumor_035.tif
# # tumor pxls:0, % tumor pxls:0.3497125, file_name:test/level5/non_tumor/level_5_38400_102400_400_tumor_035.tif
# # tumor pxls:0, % tumor pxls:0.2921375, file_name:test/level5/non_tumor/level_5_51200_89600_400_tumor_035.tif
# # tumor pxls:0, % tumor pxls:0.25823125, file_name:test/level5/non_tumor/level_5_64000_89600_400_tumor_035.tif
#
# Extracting Data w/ level=5, window_size=400, image_number=9
# # tumor pxls:54, % tumor pxls:0.10845625, file_name:validate/level5/tumor/level_5_0_140800_400_tumor_057.tif
# # tumor pxls:910, % tumor pxls:0.37755625, file_name:validate/level5/tumor/level_5_12800_140800_400_tumor_057.tif
# # tumor pxls:202, % tumor pxls:0.5018875, file_name:validate/level5/tumor/level_5_12800_153600_400_tumor_057.tif
# # tumor pxls:0, % tumor pxls:0.41790625, file_name:validate/level5/non_tumor/level_5_12800_166400_400_tumor_057.tif
# # tumor pxls:0, % tumor pxls:0.33994375, file_name:validate/level5/non_tumor/level_5_25600_102400_400_tumor_057.tif
# # tumor pxls:0, % tumor pxls:0.44423125, file_name:validate/level5/non_tumor/level_5_25600_128000_400_tumor_057.tif
# # tumor pxls:0, % tumor pxls:0.36626875, file_name:validate/level5/non_tumor/level_5_38400_102400_400_tumor_057.tif
# # tumor pxls:0, % tumor pxls:0.281675, file_name:validate/level5/non_tumor/level_5_51200_140800_400_tumor_057.tif
# # tumor pxls:0, % tumor pxls:0.48104375, file_name:validate/level5/non_tumor/level_5_51200_153600_400_tumor_057.tif
#
# Extracting Data w/ level=5, window_size=400, image_number=10
# # tumor pxls:0, % tumor pxls:0.23215625, file_name:train/level5/non_tumor/level_5_25600_128000_400_tumor_059.tif
# # tumor pxls:0, % tumor pxls:0.75244375, file_name:train/level5/non_tumor/level_5_38400_115200_400_tumor_059.tif
# # tumor pxls:0, % tumor pxls:0.56089375, file_name:train/level5/non_tumor/level_5_38400_128000_400_tumor_059.tif
# # tumor pxls:0, % tumor pxls:0.27720625, file_name:train/level5/non_tumor/level_5_38400_153600_400_tumor_059.tif
# # tumor pxls:271, % tumor pxls:0.3811125, file_name:train/level5/tumor/level_5_51200_115200_400_tumor_059.tif
# # tumor pxls:0, % tumor pxls:0.2942625, file_name:train/level5/non_tumor/level_5_51200_128000_400_tumor_059.tif
# # tumor pxls:0, % tumor pxls:0.36809375, file_name:train/level5/non_tumor/level_5_51200_140800_400_tumor_059.tif
# # tumor pxls:0, % tumor pxls:0.40395625, file_name:train/level5/non_tumor/level_5_51200_153600_400_tumor_059.tif
#
# Extracting Data w/ level=5, window_size=400, image_number=11
# # tumor pxls:2117, % tumor pxls:0.0904375, file_name:train/level5/tumor/level_5_0_153600_400_tumor_064.tif
# # tumor pxls:230, % tumor pxls:0.00618125, file_name:train/level5/tumor/level_5_12800_102400_400_tumor_064.tif
# # tumor pxls:16284, % tumor pxls:0.310725, file_name:train/level5/tumor/level_5_12800_115200_400_tumor_064.tif
# # tumor pxls:0, % tumor pxls:0.2973, file_name:train/level5/non_tumor/level_5_12800_128000_400_tumor_064.tif
# # tumor pxls:0, % tumor pxls:0.243525, file_name:train/level5/non_tumor/level_5_12800_140800_400_tumor_064.tif
# # tumor pxls:31211, % tumor pxls:0.530325, file_name:train/level5/tumor/level_5_12800_153600_400_tumor_064.tif
# # tumor pxls:22919, % tumor pxls:0.22399375, file_name:train/level5/tumor/level_5_12800_166400_400_tumor_064.tif
# # tumor pxls:162, % tumor pxls:0.0177875, file_name:train/level5/tumor/level_5_25600_102400_400_tumor_064.tif
# # tumor pxls:10159, % tumor pxls:0.13009375, file_name:train/level5/tumor/level_5_25600_115200_400_tumor_064.tif
# # tumor pxls:0, % tumor pxls:0.462175, file_name:train/level5/non_tumor/level_5_51200_140800_400_tumor_064.tif
# # tumor pxls:17661, % tumor pxls:0.41465625, file_name:train/level5/tumor/level_5_64000_128000_400_tumor_064.tif
# # tumor pxls:0, % tumor pxls:0.669275, file_name:train/level5/non_tumor/level_5_64000_140800_400_tumor_064.tif
# # tumor pxls:2684, % tumor pxls:0.3658125, file_name:train/level5/tumor/level_5_76800_128000_400_tumor_064.tif
# # tumor pxls:27268, % tumor pxls:0.5308375, file_name:train/level5/tumor/level_5_76800_140800_400_tumor_064.tif
#
# Extracting Data w/ level=5, window_size=400, image_number=12
# # tumor pxls:0, % tumor pxls:0.6489875, file_name:train/level5/non_tumor/level_5_12800_38400_400_tumor_075.tif
# # tumor pxls:0, % tumor pxls:0.5202, file_name:train/level5/non_tumor/level_5_12800_51200_400_tumor_075.tif
# # tumor pxls:23854, % tumor pxls:0.2678625, file_name:train/level5/tumor/level_5_25600_38400_400_tumor_075.tif
# # tumor pxls:15456, % tumor pxls:0.38374375, file_name:train/level5/tumor/level_5_25600_51200_400_tumor_075.tif
# # tumor pxls:3685, % tumor pxls:0.121, file_name:train/level5/tumor/level_5_51200_0_400_tumor_075.tif
# # tumor pxls:4034, % tumor pxls:0.422725, file_name:train/level5/tumor/level_5_51200_12800_400_tumor_075.tif
# # tumor pxls:0, % tumor pxls:0.3868875, file_name:train/level5/non_tumor/level_5_51200_25600_400_tumor_075.tif
# # tumor pxls:193, % tumor pxls:0.1553875, file_name:train/level5/tumor/level_5_64000_0_400_tumor_075.tif
# # tumor pxls:84, % tumor pxls:0.7918875, file_name:train/level5/tumor/level_5_64000_12800_400_tumor_075.tif
# # tumor pxls:0, % tumor pxls:0.50670625, file_name:train/level5/non_tumor/level_5_64000_25600_400_tumor_075.tif
# # tumor pxls:0, % tumor pxls:0.21270625, file_name:train/level5/non_tumor/level_5_64000_38400_400_tumor_075.tif
# # tumor pxls:0, % tumor pxls:0.22933125, file_name:train/level5/non_tumor/level_5_76800_12800_400_tumor_075.tif
#
# Extracting Data w/ level=5, window_size=400, image_number=13
# # tumor pxls:2301, % tumor pxls:0.5137, file_name:train/level5/tumor/level_5_12800_25600_400_tumor_078.tif
# # tumor pxls:19562, % tumor pxls:0.620025, file_name:train/level5/tumor/level_5_12800_38400_400_tumor_078.tif
# # tumor pxls:78085, % tumor pxls:0.84675625, file_name:train/level5/tumor/level_5_12800_51200_400_tumor_078.tif
# # tumor pxls:269, % tumor pxls:0.57220625, file_name:train/level5/tumor/level_5_12800_64000_400_tumor_078.tif
# # tumor pxls:0, % tumor pxls:0.23588125, file_name:train/level5/non_tumor/level_5_25600_0_400_tumor_078.tif
# # tumor pxls:0, % tumor pxls:0.70268125, file_name:train/level5/non_tumor/level_5_25600_12800_400_tumor_078.tif
# # tumor pxls:15181, % tumor pxls:0.9947, file_name:train/level5/tumor/level_5_25600_25600_400_tumor_078.tif
# # tumor pxls:37186, % tumor pxls:0.4747375, file_name:train/level5/tumor/level_5_25600_38400_400_tumor_078.tif
# # tumor pxls:61022, % tumor pxls:0.8923375, file_name:train/level5/tumor/level_5_25600_51200_400_tumor_078.tif
# # tumor pxls:97317, % tumor pxls:0.9987875, file_name:train/level5/tumor/level_5_25600_64000_400_tumor_078.tif
# # tumor pxls:73504, % tumor pxls:0.94624375, file_name:train/level5/tumor/level_5_25600_76800_400_tumor_078.tif
# # tumor pxls:11264, % tumor pxls:0.40626875, file_name:train/level5/tumor/level_5_25600_89600_400_tumor_078.tif
# # tumor pxls:4245, % tumor pxls:0.21990625, file_name:train/level5/tumor/level_5_38400_0_400_tumor_078.tif
# # tumor pxls:45199, % tumor pxls:0.79313125, file_name:train/level5/tumor/level_5_38400_12800_400_tumor_078.tif
# # tumor pxls:33930, % tumor pxls:0.51704375, file_name:train/level5/tumor/level_5_38400_25600_400_tumor_078.tif
# # tumor pxls:4279, % tumor pxls:0.3296, file_name:train/level5/tumor/level_5_38400_51200_400_tumor_078.tif
# # tumor pxls:39516, % tumor pxls:0.48591875, file_name:train/level5/tumor/level_5_38400_64000_400_tumor_078.tif
# # tumor pxls:98730, % tumor pxls:0.716825, file_name:train/level5/tumor/level_5_38400_76800_400_tumor_078.tif
# # tumor pxls:43689, % tumor pxls:0.3616875, file_name:train/level5/tumor/level_5_38400_89600_400_tumor_078.tif
# # tumor pxls:0, % tumor pxls:0.28850625, file_name:train/level5/non_tumor/level_5_51200_25600_400_tumor_078.tif
# # tumor pxls:1615, % tumor pxls:0.366875, file_name:train/level5/tumor/level_5_51200_38400_400_tumor_078.tif
# # tumor pxls:6656, % tumor pxls:0.47170625, file_name:train/level5/tumor/level_5_51200_51200_400_tumor_078.tif
# # tumor pxls:1174, % tumor pxls:0.65580625, file_name:train/level5/tumor/level_5_51200_64000_400_tumor_078.tif
# # tumor pxls:48147, % tumor pxls:0.5046625, file_name:train/level5/tumor/level_5_51200_76800_400_tumor_078.tif
# # tumor pxls:0, % tumor pxls:0.72825625, file_name:train/level5/non_tumor/level_5_64000_25600_400_tumor_078.tif
# # tumor pxls:44952, % tumor pxls:0.9694875, file_name:train/level5/tumor/level_5_64000_38400_400_tumor_078.tif
# # tumor pxls:71713, % tumor pxls:0.9974625, file_name:train/level5/tumor/level_5_64000_51200_400_tumor_078.tif
# # tumor pxls:35127, % tumor pxls:0.98859375, file_name:train/level5/tumor/level_5_64000_64000_400_tumor_078.tif
# # tumor pxls:50623, % tumor pxls:0.39568125, file_name:train/level5/tumor/level_5_64000_76800_400_tumor_078.tif
# # tumor pxls:37, % tumor pxls:0.04418125, file_name:train/level5/tumor/level_5_76800_38400_400_tumor_078.tif
# # tumor pxls:18138, % tumor pxls:0.27858125, file_name:train/level5/tumor/level_5_76800_51200_400_tumor_078.tif
# # tumor pxls:4775, % tumor pxls:0.08698125, file_name:train/level5/tumor/level_5_76800_64000_400_tumor_078.tif
#
# Extracting Data w/ level=5, window_size=400, image_number=14
# # tumor pxls:0, % tumor pxls:0.79901875, file_name:validate/level5/non_tumor/level_5_12800_12800_400_tumor_081.tif
# # tumor pxls:0, % tumor pxls:0.661325, file_name:validate/level5/non_tumor/level_5_12800_51200_400_tumor_081.tif
# # tumor pxls:0, % tumor pxls:0.2520375, file_name:validate/level5/non_tumor/level_5_12800_64000_400_tumor_081.tif
# # tumor pxls:0, % tumor pxls:0.25830625, file_name:validate/level5/non_tumor/level_5_25600_0_400_tumor_081.tif
# # tumor pxls:0, % tumor pxls:0.5207125, file_name:validate/level5/non_tumor/level_5_25600_12800_400_tumor_081.tif
# # tumor pxls:0, % tumor pxls:0.23255, file_name:validate/level5/non_tumor/level_5_25600_25600_400_tumor_081.tif
# # tumor pxls:0, % tumor pxls:0.4960375, file_name:validate/level5/non_tumor/level_5_25600_38400_400_tumor_081.tif
# # tumor pxls:0, % tumor pxls:0.2932, file_name:validate/level5/non_tumor/level_5_25600_51200_400_tumor_081.tif
# # tumor pxls:487, % tumor pxls:0.709575, file_name:validate/level5/tumor/level_5_38400_38400_400_tumor_081.tif
# # tumor pxls:0, % tumor pxls:0.2807875, file_name:validate/level5/non_tumor/level_5_38400_51200_400_tumor_081.tif
# # tumor pxls:0, % tumor pxls:0.203425, file_name:validate/level5/non_tumor/level_5_51200_12800_400_tumor_081.tif
# # tumor pxls:0, % tumor pxls:0.20331875, file_name:validate/level5/non_tumor/level_5_51200_51200_400_tumor_081.tif
# # tumor pxls:0, % tumor pxls:0.3019, file_name:validate/level5/non_tumor/level_5_51200_64000_400_tumor_081.tif
# # tumor pxls:0, % tumor pxls:0.21608125, file_name:validate/level5/non_tumor/level_5_51200_76800_400_tumor_081.tif
# # tumor pxls:0, % tumor pxls:0.26203125, file_name:validate/level5/non_tumor/level_5_64000_0_400_tumor_081.tif
# # tumor pxls:0, % tumor pxls:0.441075, file_name:validate/level5/non_tumor/level_5_64000_12800_400_tumor_081.tif
# # tumor pxls:0, % tumor pxls:0.6195875, file_name:validate/level5/non_tumor/level_5_64000_51200_400_tumor_081.tif
# # tumor pxls:0, % tumor pxls:0.205175, file_name:validate/level5/non_tumor/level_5_64000_64000_400_tumor_081.tif
#
# Extracting Data w/ level=5, window_size=400, image_number=15
# # tumor pxls:0, % tumor pxls:0.406625, file_name:train/level5/non_tumor/level_5_12800_12800_400_tumor_084.tif
# # tumor pxls:0, % tumor pxls:0.4240875, file_name:train/level5/non_tumor/level_5_12800_25600_400_tumor_084.tif
# # tumor pxls:5083, % tumor pxls:0.704825, file_name:train/level5/tumor/level_5_12800_38400_400_tumor_084.tif
# # tumor pxls:20385, % tumor pxls:0.94513125, file_name:train/level5/tumor/level_5_12800_51200_400_tumor_084.tif
# # tumor pxls:598, % tumor pxls:0.605625, file_name:train/level5/tumor/level_5_12800_64000_400_tumor_084.tif
# # tumor pxls:0, % tumor pxls:0.20998125, file_name:train/level5/non_tumor/level_5_25600_0_400_tumor_084.tif
# # tumor pxls:0, % tumor pxls:0.2754125, file_name:train/level5/non_tumor/level_5_25600_12800_400_tumor_084.tif
# # tumor pxls:0, % tumor pxls:0.56781875, file_name:train/level5/non_tumor/level_5_25600_38400_400_tumor_084.tif
# # tumor pxls:0, % tumor pxls:0.6957625, file_name:train/level5/non_tumor/level_5_25600_51200_400_tumor_084.tif
# # tumor pxls:0, % tumor pxls:0.33480625, file_name:train/level5/non_tumor/level_5_25600_64000_400_tumor_084.tif
# # tumor pxls:2357, % tumor pxls:0.38580625, file_name:train/level5/tumor/level_5_38400_0_400_tumor_084.tif
# # tumor pxls:3491, % tumor pxls:0.633225, file_name:train/level5/tumor/level_5_38400_12800_400_tumor_084.tif
# # tumor pxls:0, % tumor pxls:0.20779375, file_name:train/level5/non_tumor/level_5_38400_25600_400_tumor_084.tif
# # tumor pxls:0, % tumor pxls:0.37320625, file_name:train/level5/non_tumor/level_5_38400_38400_400_tumor_084.tif
# # tumor pxls:0, % tumor pxls:0.24301875, file_name:train/level5/non_tumor/level_5_38400_51200_400_tumor_084.tif
# # tumor pxls:0, % tumor pxls:0.2498375, file_name:train/level5/non_tumor/level_5_51200_12800_400_tumor_084.tif
#
# Extracting Data w/ level=5, window_size=400, image_number=16
# # tumor pxls:0, % tumor pxls:0.492525, file_name:train/level5/non_tumor/level_5_12800_12800_400_tumor_091.tif
# # tumor pxls:0, % tumor pxls:0.45561875, file_name:train/level5/non_tumor/level_5_12800_25600_400_tumor_091.tif
# # tumor pxls:0, % tumor pxls:0.22638125, file_name:train/level5/non_tumor/level_5_12800_38400_400_tumor_091.tif
# # tumor pxls:0, % tumor pxls:0.2486125, file_name:train/level5/non_tumor/level_5_25600_0_400_tumor_091.tif
# # tumor pxls:0, % tumor pxls:0.82383125, file_name:train/level5/non_tumor/level_5_25600_12800_400_tumor_091.tif
# # tumor pxls:21942, % tumor pxls:0.9173, file_name:train/level5/tumor/level_5_25600_25600_400_tumor_091.tif
# # tumor pxls:0, % tumor pxls:0.23175625, file_name:train/level5/non_tumor/level_5_25600_38400_400_tumor_091.tif
# # tumor pxls:4156, % tumor pxls:0.85986875, file_name:train/level5/tumor/level_5_38400_12800_400_tumor_091.tif
# # tumor pxls:20123, % tumor pxls:0.830575, file_name:train/level5/tumor/level_5_38400_25600_400_tumor_091.tif
# # tumor pxls:531, % tumor pxls:0.0750125, file_name:train/level5/tumor/level_5_38400_38400_400_tumor_091.tif
#
# Extracting Data w/ level=5, window_size=400, image_number=17
# # tumor pxls:0, % tumor pxls:0.33575625, file_name:test/level5/non_tumor/level_5_12800_12800_400_tumor_094.tif
# # tumor pxls:0, % tumor pxls:0.424125, file_name:test/level5/non_tumor/level_5_12800_25600_400_tumor_094.tif
# # tumor pxls:0, % tumor pxls:0.53713125, file_name:test/level5/non_tumor/level_5_25600_12800_400_tumor_094.tif
# # tumor pxls:0, % tumor pxls:0.62638125, file_name:test/level5/non_tumor/level_5_25600_25600_400_tumor_094.tif
# # tumor pxls:26, % tumor pxls:0.2701, file_name:test/level5/tumor/level_5_25600_38400_400_tumor_094.tif
# # tumor pxls:0, % tumor pxls:0.89721875, file_name:test/level5/non_tumor/level_5_25600_51200_400_tumor_094.tif
# # tumor pxls:0, % tumor pxls:0.297625, file_name:test/level5/non_tumor/level_5_25600_64000_400_tumor_094.tif
# # tumor pxls:0, % tumor pxls:0.2380625, file_name:test/level5/non_tumor/level_5_38400_12800_400_tumor_094.tif
# # tumor pxls:0, % tumor pxls:0.94233125, file_name:test/level5/non_tumor/level_5_38400_51200_400_tumor_094.tif
# # tumor pxls:0, % tumor pxls:0.69634375, file_name:test/level5/non_tumor/level_5_38400_64000_400_tumor_094.tif
# # tumor pxls:0, % tumor pxls:0.26675625, file_name:test/level5/non_tumor/level_5_38400_76800_400_tumor_094.tif
# # tumor pxls:0, % tumor pxls:0.51655625, file_name:test/level5/non_tumor/level_5_51200_51200_400_tumor_094.tif
# # tumor pxls:0, % tumor pxls:0.38018125, file_name:test/level5/non_tumor/level_5_51200_64000_400_tumor_094.tif
# # tumor pxls:0, % tumor pxls:0.6134125, file_name:test/level5/non_tumor/level_5_51200_76800_400_tumor_094.tif
# # tumor pxls:0, % tumor pxls:0.34540625, file_name:test/level5/non_tumor/level_5_64000_12800_400_tumor_094.tif
# # tumor pxls:4997, % tumor pxls:0.6679875, file_name:test/level5/tumor/level_5_64000_25600_400_tumor_094.tif
# # tumor pxls:0, % tumor pxls:0.24695625, file_name:test/level5/non_tumor/level_5_64000_38400_400_tumor_094.tif
# # tumor pxls:0, % tumor pxls:0.3814, file_name:test/level5/non_tumor/level_5_64000_76800_400_tumor_094.tif
# # tumor pxls:17, % tumor pxls:0.247875, file_name:test/level5/tumor/level_5_76800_12800_400_tumor_094.tif
# # tumor pxls:56217, % tumor pxls:0.80535, file_name:test/level5/tumor/level_5_76800_25600_400_tumor_094.tif
# # tumor pxls:0, % tumor pxls:0.23120625, file_name:test/level5/non_tumor/level_5_76800_38400_400_tumor_094.tif
# # tumor pxls:0, % tumor pxls:0.3808375, file_name:test/level5/non_tumor/level_5_89600_12800_400_tumor_094.tif
# # tumor pxls:0, % tumor pxls:0.40094375, file_name:test/level5/non_tumor/level_5_89600_25600_400_tumor_094.tif
# # tumor pxls:0, % tumor pxls:0.21710625, file_name:test/level5/non_tumor/level_5_89600_38400_400_tumor_094.tif
#
# Extracting Data w/ level=5, window_size=400, image_number=18
# # tumor pxls:0, % tumor pxls:0.25545, file_name:train/level5/non_tumor/level_5_0_38400_400_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.203375, file_name:train/level5/non_tumor/level_5_0_51200_400_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.38200625, file_name:train/level5/non_tumor/level_5_12800_0_400_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.38568125, file_name:train/level5/non_tumor/level_5_12800_12800_400_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.564075, file_name:train/level5/non_tumor/level_5_12800_38400_400_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.2795, file_name:train/level5/non_tumor/level_5_12800_51200_400_tumor_096.tif
# # tumor pxls:34, % tumor pxls:0.28605625, file_name:train/level5/tumor/level_5_25600_12800_400_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.310375, file_name:train/level5/non_tumor/level_5_25600_38400_400_tumor_096.tif
# # tumor pxls:4933, % tumor pxls:0.0991625, file_name:train/level5/tumor/level_5_38400_0_400_tumor_096.tif
# # tumor pxls:7702, % tumor pxls:0.6121375, file_name:train/level5/tumor/level_5_38400_12800_400_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.51314375, file_name:train/level5/non_tumor/level_5_38400_25600_400_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.4480125, file_name:train/level5/non_tumor/level_5_38400_38400_400_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.39944375, file_name:train/level5/non_tumor/level_5_76800_12800_400_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.49535625, file_name:train/level5/non_tumor/level_5_76800_38400_400_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.606525, file_name:train/level5/non_tumor/level_5_76800_51200_400_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.21908125, file_name:train/level5/non_tumor/level_5_89600_0_400_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.43074375, file_name:train/level5/non_tumor/level_5_89600_12800_400_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.23021875, file_name:train/level5/non_tumor/level_5_89600_38400_400_tumor_096.tif
# # tumor pxls:9061, % tumor pxls:0.48348125, file_name:train/level5/tumor/level_5_102400_12800_400_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.31809375, file_name:train/level5/non_tumor/level_5_102400_25600_400_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.627575, file_name:train/level5/non_tumor/level_5_102400_38400_400_tumor_096.tif
# # tumor pxls:925, % tumor pxls:0.27860625, file_name:train/level5/tumor/level_5_115200_12800_400_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.58108125, file_name:train/level5/non_tumor/level_5_115200_25600_400_tumor_096.tif
# # tumor pxls:0, % tumor pxls:0.351175, file_name:train/level5/non_tumor/level_5_115200_38400_400_tumor_096.tif
#
# Extracting Data w/ level=5, window_size=400, image_number=19
# # tumor pxls:14884, % tumor pxls:0.80970625, file_name:validate/level5/tumor/level_5_12800_12800_400_tumor_101.tif
# # tumor pxls:0, % tumor pxls:0.462025, file_name:validate/level5/non_tumor/level_5_12800_25600_400_tumor_101.tif
# # tumor pxls:0, % tumor pxls:0.371625, file_name:validate/level5/non_tumor/level_5_12800_38400_400_tumor_101.tif
# # tumor pxls:26814, % tumor pxls:0.75326875, file_name:validate/level5/tumor/level_5_25600_12800_400_tumor_101.tif
# # tumor pxls:0, % tumor pxls:0.50108125, file_name:validate/level5/non_tumor/level_5_25600_25600_400_tumor_101.tif
# # tumor pxls:1122, % tumor pxls:0.63975625, file_name:validate/level5/tumor/level_5_25600_38400_400_tumor_101.tif
# # tumor pxls:0, % tumor pxls:0.24059375, file_name:validate/level5/non_tumor/level_5_25600_51200_400_tumor_101.tif
# # tumor pxls:29946, % tumor pxls:0.89529375, file_name:validate/level5/tumor/level_5_38400_12800_400_tumor_101.tif
# # tumor pxls:20851, % tumor pxls:0.5594625, file_name:validate/level5/tumor/level_5_38400_25600_400_tumor_101.tif
# # tumor pxls:699, % tumor pxls:0.1664, file_name:validate/level5/tumor/level_5_38400_38400_400_tumor_101.tif
# # tumor pxls:0, % tumor pxls:0.45593125, file_name:validate/level5/non_tumor/level_5_38400_51200_400_tumor_101.tif
# # tumor pxls:0, % tumor pxls:0.36309375, file_name:validate/level5/non_tumor/level_5_51200_12800_400_tumor_101.tif
# # tumor pxls:0, % tumor pxls:0.2413625, file_name:validate/level5/non_tumor/level_5_51200_51200_400_tumor_101.tif
# # tumor pxls:0, % tumor pxls:0.286225, file_name:validate/level5/non_tumor/level_5_76800_12800_400_tumor_101.tif
# # tumor pxls:26592, % tumor pxls:0.93063125, file_name:validate/level5/tumor/level_5_89600_12800_400_tumor_101.tif
# # tumor pxls:0, % tumor pxls:0.53343125, file_name:validate/level5/non_tumor/level_5_89600_25600_400_tumor_101.tif
# # tumor pxls:0, % tumor pxls:0.456125, file_name:validate/level5/non_tumor/level_5_89600_38400_400_tumor_101.tif
# # tumor pxls:23472, % tumor pxls:0.71706875, file_name:validate/level5/tumor/level_5_102400_12800_400_tumor_101.tif
# # tumor pxls:7062, % tumor pxls:0.491525, file_name:validate/level5/tumor/level_5_102400_25600_400_tumor_101.tif
# # tumor pxls:1823, % tumor pxls:0.4702, file_name:validate/level5/tumor/level_5_102400_38400_400_tumor_101.tif
# # tumor pxls:0, % tumor pxls:0.38621875, file_name:validate/level5/non_tumor/level_5_102400_51200_400_tumor_101.tif
# # tumor pxls:0, % tumor pxls:0.30010625, file_name:validate/level5/non_tumor/level_5_115200_0_400_tumor_101.tif
# # tumor pxls:25295, % tumor pxls:0.9931875, file_name:validate/level5/tumor/level_5_115200_12800_400_tumor_101.tif
# # tumor pxls:9020, % tumor pxls:0.4509875, file_name:validate/level5/tumor/level_5_115200_25600_400_tumor_101.tif
# # tumor pxls:0, % tumor pxls:0.4422125, file_name:validate/level5/non_tumor/level_5_115200_51200_400_tumor_101.tif
#
# Extracting Data w/ level=5, window_size=400, image_number=20
# # tumor pxls:75797, % tumor pxls:0.48505625, file_name:train/level5/tumor/level_5_12800_12800_400_tumor_110.tif
# # tumor pxls:68294, % tumor pxls:0.8683, file_name:train/level5/tumor/level_5_12800_25600_400_tumor_110.tif
# # tumor pxls:64877, % tumor pxls:0.9650625, file_name:train/level5/tumor/level_5_12800_38400_400_tumor_110.tif
# # tumor pxls:20744, % tumor pxls:0.45998125, file_name:train/level5/tumor/level_5_12800_51200_400_tumor_110.tif
# # tumor pxls:18130, % tumor pxls:0.14454375, file_name:train/level5/tumor/level_5_25600_0_400_tumor_110.tif
# # tumor pxls:132359, % tumor pxls:0.8658125, file_name:train/level5/tumor/level_5_25600_12800_400_tumor_110.tif
# # tumor pxls:62055, % tumor pxls:0.96648125, file_name:train/level5/tumor/level_5_25600_25600_400_tumor_110.tif
# # tumor pxls:66660, % tumor pxls:0.9586375, file_name:train/level5/tumor/level_5_25600_38400_400_tumor_110.tif
# # tumor pxls:113132, % tumor pxls:0.8278125, file_name:train/level5/tumor/level_5_25600_51200_400_tumor_110.tif
# # tumor pxls:47471, % tumor pxls:0.355325, file_name:train/level5/tumor/level_5_38400_0_400_tumor_110.tif
# # tumor pxls:141150, % tumor pxls:0.97493125, file_name:train/level5/tumor/level_5_38400_12800_400_tumor_110.tif
# # tumor pxls:8800, % tumor pxls:0.950425, file_name:train/level5/tumor/level_5_38400_25600_400_tumor_110.tif
# # tumor pxls:7260, % tumor pxls:0.95143125, file_name:train/level5/tumor/level_5_38400_38400_400_tumor_110.tif
# # tumor pxls:40029, % tumor pxls:0.30853125, file_name:train/level5/tumor/level_5_38400_51200_400_tumor_110.tif
# # tumor pxls:2930, % tumor pxls:0.075275, file_name:train/level5/tumor/level_5_51200_0_400_tumor_110.tif
# # tumor pxls:83709, % tumor pxls:0.7628625, file_name:train/level5/tumor/level_5_51200_12800_400_tumor_110.tif
# # tumor pxls:65286, % tumor pxls:0.81864375, file_name:train/level5/tumor/level_5_51200_25600_400_tumor_110.tif
# # tumor pxls:9382, % tumor pxls:0.340625, file_name:train/level5/tumor/level_5_51200_38400_400_tumor_110.tif

# %% [markdown]
# ### Running for level 3 with window size 800

# %%
LEVEL = 3
SLIDING_WINDOW = 800
IS_SAMPLING = True

extract_data_by_level(LEVEL, 
                      masks_slides,
                      SLIDING_WINDOW, 
                      IS_SAMPLING)
# Out:
# GCP Train Data Paths:
# train/level3/tumor
# train/level3/non_tumor
#
# GCP Validate Data Paths:
# validate/level3/tumor
# validate/level3/non_tumor
#
# GCP Test Data Paths:
# test/level3/tumor
# test/level3/non_tumor
#
# Extracting Data w/ level=3, window_size=800, image_number=0
# Discard Non tumor image:  DISCARD/level_3_0_0_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_0_121600_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_0_128000_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_0_134400_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.25999375, file_name:train/level3/non_tumor/level_3_6400_0_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.266809375, file_name:train/level3/non_tumor/level_3_6400_76800_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.242978125, file_name:train/level3/non_tumor/level_3_6400_83200_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.4643921875, file_name:train/level3/non_tumor/level_3_6400_121600_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.807453125, file_name:train/level3/non_tumor/level_3_6400_128000_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.2371734375, file_name:train/level3/non_tumor/level_3_12800_0_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.5951609375, file_name:train/level3/non_tumor/level_3_12800_12800_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.6652828125, file_name:train/level3/non_tumor/level_3_12800_76800_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_12800_83200_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.670021875, file_name:train/level3/non_tumor/level_3_12800_89600_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.227775, file_name:train/level3/non_tumor/level_3_19200_0_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_19200_70400_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_19200_76800_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_19200_83200_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.737240625, file_name:train/level3/non_tumor/level_3_19200_89600_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_19200_96000_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_19200_115200_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.2596796875, file_name:train/level3/non_tumor/level_3_19200_153600_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.2303984375, file_name:train/level3/non_tumor/level_3_25600_0_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_25600_64000_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_25600_70400_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.874796875, file_name:train/level3/non_tumor/level_3_25600_76800_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_25600_83200_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.745415625, file_name:train/level3/non_tumor/level_3_25600_89600_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.2585390625, file_name:train/level3/non_tumor/level_3_25600_108800_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.4709015625, file_name:train/level3/non_tumor/level_3_25600_115200_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_32000_0_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.8192703125, file_name:train/level3/non_tumor/level_3_32000_64000_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_32000_70400_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.6921015625, file_name:train/level3/non_tumor/level_3_32000_76800_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_32000_83200_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.2030296875, file_name:train/level3/non_tumor/level_3_32000_96000_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_38400_0_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_38400_64000_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_38400_70400_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_38400_76800_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_38400_108800_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_38400_115200_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_44800_70400_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_44800_76800_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_44800_83200_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.493378125, file_name:train/level3/non_tumor/level_3_44800_89600_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.3019421875, file_name:train/level3/non_tumor/level_3_44800_115200_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.4738328125, file_name:train/level3/non_tumor/level_3_44800_128000_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.2474203125, file_name:train/level3/non_tumor/level_3_51200_76800_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.36709375, file_name:train/level3/non_tumor/level_3_51200_83200_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_51200_115200_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.5542296875, file_name:train/level3/non_tumor/level_3_51200_121600_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.7431515625, file_name:train/level3/non_tumor/level_3_51200_128000_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_51200_134400_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.7505140625, file_name:train/level3/non_tumor/level_3_57600_115200_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_57600_121600_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_57600_128000_800_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.2348015625, file_name:train/level3/non_tumor/level_3_64000_0_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_64000_115200_800_tumor_001.tif
# # tumor pxls:9922, % tumor pxls:0.91654375, file_name:train/level3/tumor/level_3_64000_121600_800_tumor_001.tif
# # tumor pxls:1897, % tumor pxls:0.9275359375, file_name:train/level3/tumor/level_3_64000_128000_800_tumor_001.tif
# # tumor pxls:1268, % tumor pxls:0.40631875, file_name:train/level3/tumor/level_3_64000_134400_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_70400_0_800_tumor_001.tif
# # tumor pxls:137065, % tumor pxls:0.5671875, file_name:train/level3/tumor/level_3_70400_121600_800_tumor_001.tif
# # tumor pxls:27190, % tumor pxls:0.3603375, file_name:train/level3/tumor/level_3_70400_128000_800_tumor_001.tif
# # tumor pxls:410, % tumor pxls:0.097075, file_name:train/level3/tumor/level_3_70400_134400_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_83200_0_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_83200_12800_800_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_3_89600_0_800_tumor_001.tif
#
# Extracting Data w/ level=3, window_size=800, image_number=1
# Discard Non tumor image:  DISCARD/level_3_19200_96000_800_tumor_002.tif
# Discard Non tumor image:  DISCARD/level_3_19200_102400_800_tumor_002.tif
# Discard Non tumor image:  DISCARD/level_3_19200_108800_800_tumor_002.tif
# Discard Non tumor image:  DISCARD/level_3_25600_89600_800_tumor_002.tif
# # tumor pxls:0, % tumor pxls:0.823896875, file_name:train/level3/non_tumor/level_3_25600_96000_800_tumor_002.tif
# Discard Non tumor image:  DISCARD/level_3_25600_102400_800_tumor_002.tif
# Discard Non tumor image:  DISCARD/level_3_25600_108800_800_tumor_002.tif
# # tumor pxls:0, % tumor pxls:0.7951296875, file_name:train/level3/non_tumor/level_3_32000_89600_800_tumor_002.tif
# Discard Non tumor image:  DISCARD/level_3_32000_96000_800_tumor_002.tif
# Discard Non tumor image:  DISCARD/level_3_32000_102400_800_tumor_002.tif
# # tumor pxls:0, % tumor pxls:0.2926453125, file_name:train/level3/non_tumor/level_3_32000_108800_800_tumor_002.tif
# # tumor pxls:0, % tumor pxls:0.2318921875, file_name:train/level3/non_tumor/level_3_32000_140800_800_tumor_002.tif
# # tumor pxls:0, % tumor pxls:0.47746875, file_name:train/level3/non_tumor/level_3_38400_89600_800_tumor_002.tif
# Discard Non tumor image:  DISCARD/level_3_38400_96000_800_tumor_002.tif
# # tumor pxls:0, % tumor pxls:0.8320765625, file_name:train/level3/non_tumor/level_3_38400_102400_800_tumor_002.tif
# # tumor pxls:0, % tumor pxls:0.603109375, file_name:train/level3/non_tumor/level_3_38400_108800_800_tumor_002.tif
# Discard Non tumor image:  DISCARD/level_3_38400_115200_800_tumor_002.tif
# Discard Non tumor image:  DISCARD/level_3_38400_140800_800_tumor_002.tif
# # tumor pxls:0, % tumor pxls:0.2779484375, file_name:train/level3/non_tumor/level_3_44800_96000_800_tumor_002.tif
# # tumor pxls:14982, % tumor pxls:0.2125171875, file_name:train/level3/tumor/level_3_44800_102400_800_tumor_002.tif
# Discard Non tumor image:  DISCARD/level_3_44800_140800_800_tumor_002.tif
# # tumor pxls:0, % tumor pxls:0.61384375, file_name:train/level3/non_tumor/level_3_44800_147200_800_tumor_002.tif
# Discard Non tumor image:  DISCARD/level_3_51200_147200_800_tumor_002.tif
# Discard Non tumor image:  DISCARD/level_3_57600_115200_800_tumor_002.tif
# # tumor pxls:0, % tumor pxls:0.3612, file_name:train/level3/non_tumor/level_3_57600_121600_800_tumor_002.tif
# Discard Non tumor image:  DISCARD/level_3_64000_108800_800_tumor_002.tif
# Discard Non tumor image:  DISCARD/level_3_64000_115200_800_tumor_002.tif
# # tumor pxls:0, % tumor pxls:0.5353765625, file_name:train/level3/non_tumor/level_3_64000_121600_800_tumor_002.tif
#
# Extracting Data w/ level=3, window_size=800, image_number=2
# ---------------------------------------------------------------------------
# OpenSlideUnsupportedFormatError           Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/openslide/__init__.py in open_slide(filename)
#     381     try:
# --> 382         return OpenSlide(filename)
#     383     except OpenSlideUnsupportedFormatError:
#
# /usr/local/lib/python3.6/dist-packages/openslide/__init__.py in __init__(self, filename)
#     153         self._filename = filename
# --> 154         self._osr = lowlevel.open(filename)
#     155
#
# /usr/local/lib/python3.6/dist-packages/openslide/lowlevel.py in _check_open(result, _func, _args)
#     173         raise OpenSlideUnsupportedFormatError(
# --> 174                 "Unsupported or missing image file")
#     175     slide = _OpenSlide(c_void_p(result))
#
# OpenSlideUnsupportedFormatError: Unsupported or missing image file
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-faa92e5ecf62> in <module>()
#       6                       masks_slides,
#       7                       SLIDING_WINDOW,
# ----> 8                       IS_SAMPLING)
#
# <ipython-input-10-d7724910f678> in extract_data_by_level(level, masks_slides, slide_window, is_sampling)
#      32     slide_file = slide_masks[1]
#      33     tumor_mask_file =slide_masks[0]
# ---> 34     slide, tumor_mask = getSlide_Mask(slide_file, tumor_mask_file)
#      35
#      36     if (i+1)%5 == 0:
#
# <ipython-input-9-5a73c7d46232> in getSlide_Mask(slide_file, tumor_mask_file)
#       8
#       9   slide = open_slide(slide_path)
# ---> 10   tumor_mask = open_slide(tumor_mask_path)
#      11
#      12   # some slides have more than 8 levels, since we will only use the first 8 levels
#
# /usr/local/lib/python3.6/dist-packages/openslide/__init__.py in open_slide(filename)
#     382         return OpenSlide(filename)
#     383     except OpenSlideUnsupportedFormatError:
# --> 384         return ImageSlide(filename)
#     385
#     386
#
# /usr/local/lib/python3.6/dist-packages/openslide/__init__.py in __init__(self, file)
#     277         else:
#     278             self._close = True
# --> 279             self._image = Image.open(file)
#     280
#     281     def __repr__(self):
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2570         fp.close()
#    2571     raise IOError("cannot identify image file %r"
# -> 2572                   % (filename if filename else fp))
#    2573
#    2574 #
#
# OSError: cannot identify image file '/tmp/drive/My Drive/slides/tumor_005_mask.tif'

# %% [markdown]
# ### Running for level 1 with window size 3200

# %%
LEVEL = 1
SLIDING_WINDOW = 3200
IS_SAMPLING = True

extract_data_by_level(LEVEL, 
                      masks_slides,
                      SLIDING_WINDOW,
                      IS_SAMPLING)
# Out:
# GCP Train Data Paths:
# train/level1/tumor
# train/level1/non_tumor
#
# GCP Validate Data Paths:
# validate/level1/tumor
# validate/level1/non_tumor
#
# GCP Test Data Paths:
# test/level1/tumor
# test/level1/non_tumor
#
# Extracting Data w/ level=1, window_size=3200, image_number=0
# Discard Non tumor image:  DISCARD/level_1_0_0_3200_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_1_0_121600_3200_tumor_001.tif
# Discard Non tumor image:  DISCARD/level_1_0_128000_3200_tumor_001.tif
# # tumor pxls:0, % tumor pxls:0.27817412109375, file_name:train/level1/non_tumor/level_1_0_134400_3200_tumor_001.tif
# ---------------------------------------------------------------------------
# OpenSlideError                            Traceback (most recent call last)
# <ipython-input-25-9a01257962dc> in <module>()
#       6                       masks_slides,
#       7                       SLIDING_WINDOW,
# ----> 8                       IS_SAMPLING)
#
# <ipython-input-23-d7724910f678> in extract_data_by_level(level, masks_slides, slide_window, is_sampling)
#      53                      NON_TUMOR_FOLDER,
#      54                      slide_file,
# ---> 55                      is_sampling)
#
# <ipython-input-22-5a73c7d46232> in getTraining_Data(level, slide, tumor_mask, slide_window, tumor_path, non_tumor_path, slide_file, is_sampling, min_x, min_y, cancer_thres, tissue_thres)
#      80                            level=level,
#      81                            width= int(slide_width_2) ,
# ---> 82                            height= int(slide_height_2) )
#      83
#      84
#
# <ipython-input-22-5a73c7d46232> in read_slide(slide, x, y, level, width, height, as_float)
#      24
#      25 def read_slide(slide, x, y, level, width, height, as_float=False):
# ---> 26     im = slide.read_region((x,y), level, (width, height))
#      27     im = im.convert('RGB') # drop the alpha channel
#      28     if as_float:
#
# /usr/local/lib/python3.6/dist-packages/openslide/__init__.py in read_region(self, location, level, size)
#     221         function is not premultiplied."""
#     222         return lowlevel.read_region(self._osr, location[0], location[1],
# --> 223                 level, size[0], size[1])
#     224
#     225
#
# /usr/local/lib/python3.6/dist-packages/openslide/lowlevel.py in read_region(slide, x, y, level, w, h)
#     257         return PIL.Image.new('RGBA', (w, h))
#     258     buf = (w * h * c_uint32)()
# --> 259     _read_region(slide, buf, x, y, level, w, h)
#     260     return _load_image(buf, (w, h))
#     261
#
# /usr/local/lib/python3.6/dist-packages/openslide/lowlevel.py in _check_error(result, func, args)
#     194     err = get_error(args[0])
#     195     if err is not None:
# --> 196         raise OpenSlideError(err)
#     197     return _check_string(result, func, args)
#     198
#
# OpenSlideError: Cannot read raw tile
