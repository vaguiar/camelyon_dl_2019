# %% [markdown]
# <a href="https://colab.research.google.com/github/vaguiar/camelyon_dl_2019/blob/data-exploration/training_at_level_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip  install tf-nightly-2.0-preview
# Out:
# Requirement already satisfied: tf-nightly-2.0-preview in /usr/local/lib/python3.6/dist-packages (2.0.0.dev20190512)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (0.1.6)
# Requirement already satisfied: tb-nightly<1.15.0a0,>=1.14.0a0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (1.14.0a20190512)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (1.16.3)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (1.0.7)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (1.12.0)
# Requirement already satisfied: tensorflow-estimator-2.0-preview in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (1.14.0.dev2019051200)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (1.15.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (0.2.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (1.11.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (1.0.9)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (1.1.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (0.7.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (0.33.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (3.7.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly-2.0-preview) (0.7.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.15.0a0,>=1.14.0a0->tf-nightly-2.0-preview) (0.15.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.15.0a0,>=1.14.0a0->tf-nightly-2.0-preview) (3.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tf-nightly-2.0-preview) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tf-nightly-2.0-preview) (41.0.1)

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

# The code in this notebook should work identically in TF v1 and v2
import tensorflow as tf
import zipfile

import tensorflow.keras.applications as applications
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

print("You have version", tf.__version__)
assert tf.__version__ >= "2.0" # TensorFlow ≥ 2.0 required
# Out:
# You have version 2.0.0-dev20190512

# %% [markdown]
# ### Global constants

# %%
# Images will be resized to(TARGET_SHAPE, TARGET_SHAPE) as they're read off disk.
TARGET_SHAPE = 160 
BATCH_SIZE = 25

CLASS_MODE = 'categorical'

NUM_OF_CLASSES = 2
CLASS_NAMES = ['tumor', 'non_tumor']

# %% [markdown]
# ### Setting up GCP

# %%
GCP_PROJECT_ID = 'triple-voyage-239123'
GCP_BUCKET_NAME = 'vaa2114_dl_2019'

# %%
# !gcloud config set project {GCP_PROJECT_ID}
# Out:
# Updated property [core/project].

# %% [markdown]
# ### Read Data from GCP

# %%
LEVEL = 5

# %%
TRAIN_DIR = "/tmp/train/"
GCP_TRAIN_DIR = "train/level{}/".format(LEVEL)
LEVEL_TRAIN_DIR = "/tmp/train/level{}".format(LEVEL)

VAL_DIR = "/tmp/validate/"
GCP_VAL_DIR = "validate/level{}/".format(LEVEL)
LEVEL_VAL_DIR = "/tmp/validate/level{}".format(LEVEL)

TEST_DIR = "/tmp/test/"
GCP_TEST_DIR = "test/level{}/".format(LEVEL)
LEVEL_TEST_DIR = "/tmp/test/level{}".format(LEVEL)

# %%
# !rm -rf '$TRAIN_DIR'
# !rm -rf '$VAL_DIR'
# !rm -rf '$TEST_DIR'

# !mkdir -p '$TRAIN_DIR'
# !mkdir -p '$VAL_DIR'
# !mkdir -p '$TEST_DIR'

# %% [markdown]
# ### Download Training set

# %%
# !gsutil -m cp -r gs://{GCP_BUCKET_NAME}/{GCP_TRAIN_DIR} {TRAIN_DIR}
  
print("\nDownloaded Train Data")

print("# Non Tumor files")
# !ls "$LEVEL_TRAIN_DIR/non_tumor/" | wc -l
print("# Tumor files")
# !ls "$LEVEL_TRAIN_DIR/tumor/" | wc -l
# Out:
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_0_115200_400_tumor_001.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_0_128000_400_tumor_001.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_0_38400_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_0_51200_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_102400_25600_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_102400_38400_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_115200_25600_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_115200_38400_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_12800_0_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_12800_102400_400_tumor_002.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_12800_115200_400_tumor_001.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_12800_128000_400_tumor_064.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_12800_12800_400_tumor_091.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_12800_12800_400_tumor_084.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_12800_12800_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_12800_25600_400_tumor_091.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_12800_166400_400_tumor_005.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_12800_140800_400_tumor_064.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_12800_25600_400_tumor_084.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_12800_38400_400_tumor_075.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_12800_38400_400_tumor_091.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_12800_38400_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_12800_51200_400_tumor_075.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_12800_51200_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_12800_76800_400_tumor_001.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_12800_89600_400_tumor_001.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_0_400_tumor_084.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_0_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_0_400_tumor_091.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_102400_400_tumor_002.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_115200_400_tumor_023.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_128000_400_tumor_023.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_12800_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_12800_400_tumor_084.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_128000_400_tumor_059.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_12800_400_tumor_091.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_140800_400_tumor_005.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_153600_400_tumor_005.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_140800_400_tumor_023.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_166400_400_tumor_005.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_38400_400_tumor_084.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_38400_400_tumor_091.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_38400_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_64000_400_tumor_001.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_51200_400_tumor_084.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_64000_400_tumor_084.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_76800_400_tumor_001.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_89600_400_tumor_001.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_25600_89600_400_tumor_002.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_102400_400_tumor_001.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_115200_400_tumor_001.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_115200_400_tumor_012.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_115200_400_tumor_059.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_128000_400_tumor_001.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_128000_400_tumor_012.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_128000_400_tumor_059.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_140800_400_tumor_005.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_140800_400_tumor_002.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_140800_400_tumor_023.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_153600_400_tumor_005.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_153600_400_tumor_059.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_166400_400_tumor_005.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_25600_400_tumor_084.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_38400_400_tumor_084.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_25600_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_51200_400_tumor_012.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_51200_400_tumor_084.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_64000_400_tumor_001.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_38400_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_76800_400_tumor_001.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_38400_89600_400_tumor_002.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_51200_102400_400_tumor_012.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_51200_115200_400_tumor_001.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_51200_102400_400_tumor_031.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_51200_115200_400_tumor_002.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_51200_115200_400_tumor_012.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_51200_128000_400_tumor_001.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_51200_128000_400_tumor_012.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_51200_128000_400_tumor_059.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_51200_12800_400_tumor_084.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_51200_140800_400_tumor_005.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_51200_140800_400_tumor_019.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_51200_140800_400_tumor_059.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_51200_153600_400_tumor_059.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_51200_140800_400_tumor_064.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_51200_25600_400_tumor_075.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_51200_25600_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_51200_51200_400_tumor_012.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_51200_89600_400_tumor_012.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_64000_115200_400_tumor_002.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_51200_64000_400_tumor_012.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_64000_115200_400_tumor_012.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_64000_128000_400_tumor_023.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_64000_140800_400_tumor_019.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_64000_140800_400_tumor_023.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_64000_140800_400_tumor_064.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_64000_153600_400_tumor_019.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_64000_153600_400_tumor_023.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_64000_25600_400_tumor_075.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_64000_25600_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_64000_38400_400_tumor_075.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_64000_51200_400_tumor_012.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_64000_76800_400_tumor_019.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_76800_12800_400_tumor_075.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_76800_12800_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_76800_38400_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_76800_51200_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_89600_0_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_89600_12800_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/non_tumor/level_5_89600_38400_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_0_153600_400_tumor_064.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_115200_12800_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_102400_12800_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_12800_102400_400_tumor_064.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_12800_115200_400_tumor_064.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_12800_12800_400_tumor_110.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_12800_153600_400_tumor_064.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_12800_166400_400_tumor_064.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_12800_25600_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_12800_25600_400_tumor_110.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_12800_38400_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_12800_38400_400_tumor_084.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_12800_38400_400_tumor_110.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_12800_51200_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_12800_51200_400_tumor_084.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_12800_51200_400_tumor_110.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_12800_64000_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_12800_64000_400_tumor_084.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_25600_0_400_tumor_110.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_25600_102400_400_tumor_064.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_25600_115200_400_tumor_064.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_25600_12800_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_25600_12800_400_tumor_110.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_25600_25600_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_25600_25600_400_tumor_091.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_25600_25600_400_tumor_110.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_25600_38400_400_tumor_075.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_25600_38400_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_25600_38400_400_tumor_110.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_25600_51200_400_tumor_075.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_25600_51200_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_25600_51200_400_tumor_110.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_25600_64000_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_25600_76800_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_25600_89600_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_0_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_0_400_tumor_084.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_0_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_0_400_tumor_110.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_102400_400_tumor_002.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_115200_400_tumor_023.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_128000_400_tumor_023.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_128000_400_tumor_031.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_12800_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_12800_400_tumor_084.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_12800_400_tumor_091.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_12800_400_tumor_096.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_12800_400_tumor_110.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_140800_400_tumor_031.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_153600_400_tumor_031.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_166400_400_tumor_031.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_25600_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_25600_400_tumor_091.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_25600_400_tumor_110.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_38400_400_tumor_091.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_38400_400_tumor_110.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_51200_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_51200_400_tumor_110.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_64000_400_tumor_012.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_64000_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_76800_400_tumor_012.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_76800_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_38400_89600_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_51200_0_400_tumor_075.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_51200_0_400_tumor_110.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_51200_115200_400_tumor_059.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_51200_128000_400_tumor_005.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_51200_12800_400_tumor_075.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_51200_12800_400_tumor_110.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_51200_140800_400_tumor_031.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_51200_153600_400_tumor_031.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_51200_166400_400_tumor_031.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_51200_25600_400_tumor_110.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_51200_38400_400_tumor_110.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_51200_38400_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_51200_51200_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_51200_64000_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_51200_76800_400_tumor_019.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_51200_76800_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_51200_89600_400_tumor_019.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_64000_0_400_tumor_075.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_64000_115200_400_tumor_001.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_64000_128000_400_tumor_001.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_64000_128000_400_tumor_064.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_64000_12800_400_tumor_075.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_64000_38400_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_64000_51200_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_64000_64000_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_64000_76800_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_76800_128000_400_tumor_064.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_76800_140800_400_tumor_023.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_76800_140800_400_tumor_064.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_76800_38400_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_76800_51200_400_tumor_078.tif...
# Copying gs://vaa2114_dl_2019/train/level5/tumor/level_5_76800_64000_400_tumor_078.tif...
# / [205/205 files][ 83.8 MiB/ 83.8 MiB] 100% Done
# Operation completed over 205 objects/83.8 MiB.
#
# Downloaded Train Data
# # Non Tumor files
# 110
# # Tumor files
# 95

# %% [markdown]
# ### Download Validation Set

# %%
# !gsutil -m cp -r gs://{GCP_BUCKET_NAME}/{GCP_VAL_DIR} {VAL_DIR}
 
print("\nDownloaded Validation Data")

print("# Non Tumor files")
# !ls "$LEVEL_VAL_DIR/non_tumor/" | wc -l
print("# Tumor files")
# !ls "$LEVEL_VAL_DIR/tumor/" | wc -l
# Out:
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_102400_51200_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_115200_0_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_115200_51200_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_12800_12800_400_tumor_081.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_12800_25600_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_12800_166400_400_tumor_057.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_12800_38400_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_12800_51200_400_tumor_081.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_12800_64000_400_tumor_081.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_25600_0_400_tumor_081.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_25600_102400_400_tumor_057.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_25600_128000_400_tumor_016.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_25600_128000_400_tumor_057.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_25600_12800_400_tumor_081.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_25600_25600_400_tumor_081.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_25600_25600_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_25600_51200_400_tumor_081.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_25600_38400_400_tumor_081.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_25600_51200_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_38400_102400_400_tumor_057.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_38400_128000_400_tumor_016.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_38400_51200_400_tumor_081.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_38400_51200_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_51200_102400_400_tumor_016.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_51200_12800_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_51200_12800_400_tumor_081.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_51200_140800_400_tumor_057.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_51200_140800_400_tumor_016.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_51200_153600_400_tumor_057.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_51200_51200_400_tumor_081.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_51200_51200_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_51200_64000_400_tumor_081.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_51200_76800_400_tumor_081.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_64000_0_400_tumor_081.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_51200_89600_400_tumor_016.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_64000_12800_400_tumor_081.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_64000_64000_400_tumor_081.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_76800_12800_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_89600_25600_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_64000_51200_400_tumor_081.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/non_tumor/level_5_89600_38400_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_0_140800_400_tumor_057.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_102400_12800_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_102400_25600_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_102400_38400_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_115200_12800_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_115200_25600_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_12800_12800_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_12800_140800_400_tumor_057.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_12800_153600_400_tumor_057.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_25600_12800_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_25600_140800_400_tumor_016.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_25600_153600_400_tumor_016.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_25600_166400_400_tumor_016.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_25600_38400_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_38400_12800_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_38400_140800_400_tumor_016.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_38400_153600_400_tumor_016.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_38400_166400_400_tumor_016.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_38400_25600_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_38400_38400_400_tumor_081.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_38400_38400_400_tumor_101.tif...
# Copying gs://vaa2114_dl_2019/validate/level5/tumor/level_5_89600_12800_400_tumor_101.tif...
# \ [63/63 files][ 24.8 MiB/ 24.8 MiB] 100% Done
# Operation completed over 63 objects/24.8 MiB.
#
# Downloaded Validation Data
# # Non Tumor files
# 41
# # Tumor files
# 22

# %% [markdown]
# ### Download Test Set

# %%
# !gsutil -m cp -r gs://{GCP_BUCKET_NAME}/{GCP_TEST_DIR} {TEST_DIR}
 
print("\nDownloaded Test Data")

print("# Non Tumor files")
# !ls "$LEVEL_TEST_DIR/non_tumor/" | wc -l
print("# Tumor files")
# !ls "$LEVEL_TEST_DIR/tumor/" | wc -l
# Out:
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_12800_12800_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_12800_25600_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_25600_12800_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_25600_25600_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_25600_102400_400_tumor_035.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_25600_51200_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_25600_64000_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_25600_64000_400_tumor_035.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_25600_76800_400_tumor_035.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_25600_89600_400_tumor_035.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_38400_102400_400_tumor_035.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_38400_12800_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_38400_51200_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_38400_64000_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_38400_76800_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_51200_51200_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_51200_64000_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_51200_76800_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_51200_89600_400_tumor_035.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_64000_38400_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_64000_12800_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_64000_76800_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_64000_89600_400_tumor_035.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_76800_38400_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_89600_12800_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_89600_25600_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/non_tumor/level_5_89600_38400_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/tumor/level_5_25600_38400_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/tumor/level_5_38400_76800_400_tumor_035.tif...
# Copying gs://vaa2114_dl_2019/test/level5/tumor/level_5_38400_89600_400_tumor_035.tif...
# Copying gs://vaa2114_dl_2019/test/level5/tumor/level_5_64000_25600_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/tumor/level_5_76800_12800_400_tumor_094.tif...
# Copying gs://vaa2114_dl_2019/test/level5/tumor/level_5_76800_25600_400_tumor_094.tif...
# - [33/33 files][ 14.9 MiB/ 14.9 MiB] 100% Done
# Operation completed over 33 objects/14.9 MiB.
#
# Downloaded Test Data
# # Non Tumor files
# 27
# # Tumor files
# 6

# %%
train_tumor_dir = os.path.join(LEVEL_TRAIN_DIR, "tumor")
train_non_tumor_dir = os.path.join(LEVEL_TRAIN_DIR, "non_tumor")

val_tumor_dir = os.path.join(LEVEL_VAL_DIR, "tumor")
val_non_tumor_dir = os.path.join(LEVEL_VAL_DIR, "non_tumor")

test_tumor_dir = os.path.join(LEVEL_TEST_DIR, "tumor")
test_non_tumor_dir = os.path.join(LEVEL_TEST_DIR, "non_tumor")


tot_train_tumor = len(os.listdir(train_tumor_dir))
tot_train_non_tumor = len(os.listdir(train_non_tumor_dir))

tot_val_tumor = len(os.listdir(val_tumor_dir))
tot_val_non_tumor = len(os.listdir(val_non_tumor_dir))

tot_test_tumor = len(os.listdir(test_tumor_dir))
tot_test_non_tumor = len(os.listdir(test_non_tumor_dir))

total_train = tot_train_tumor + tot_train_non_tumor
total_val = tot_val_tumor + tot_val_non_tumor
total_test = tot_test_tumor + tot_test_non_tumor

print("Total Train:", total_train)
print("Total Val:", total_val)
print("Total Test:", total_test)
# Out:
# Total Train: 205
# Total Val: 63
# Total Test: 33

# %% [markdown]
# ### Extracting the Window size from the file name

# %%
WINDOW = int(os.listdir(train_tumor_dir)[0].split('_')[4])
print("SLIDING WINDOW SIZE: ", WINDOW)
# Out:
# SLIDING WINDOW SIZE:  400

# %% [markdown]
# ### Util functions

# %%
# This function will plot images in a grid with 1 row and 5 columns
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip( images_arr, axes):
        ax.grid(False)
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
def getModel(conv_base):
  model = Sequential()
  model.add(conv_base)
  model.add(Flatten())
  model.add(Dropout(0.5))
  model.add(Dense(216, activation='relu'))
  model.add(Dense(NUM_OF_CLASSES, activation='softmax'))
  
  return model

# %%
# Compile and build

def trainModel(model, total_train, total_val, 
               train_data_gen, val_data_gen, EPOCHS):
  model.compile(loss='categorical_crossentropy',
                optimizer='adam',
                metrics=['acc'])

  history = model.fit_generator(
        train_data_gen,
        steps_per_epoch=int(np.ceil(total_train / float(BATCH_SIZE))),
        epochs=EPOCHS,
        validation_data=val_data_gen,
        validation_steps=int(np.ceil(total_val / float(BATCH_SIZE))),
        verbose=2)
  
  return history

# %%
# Print Train/Validate accuracy and loss

def plotTrainVal(history, EPOCHS):

  acc = history.history['acc']
  val_acc = history.history['val_acc']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs_range = range(1, EPOCHS+1)

  plt.figure(figsize=(8, 8))
  plt.subplot(1, 2, 1)
  plt.plot(epochs_range, acc, label='Training Accuracy')
  plt.plot(epochs_range, val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.title('Training and Validation Accuracy')

  plt.subplot(1, 2, 2)
  plt.plot(epochs_range, loss, label='Training Loss')
  plt.plot(epochs_range, val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Training and Validation Loss')
  plt.show()

# %%
import itertools
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %% [markdown]
# ### Image Generators w/ Data Augmentation
#
# Rerun before each model training

# %%
# Images will be resized to(TARGET_SHAPE, TARGET_SHAPE) as they're read off disk.
TARGET_SHAPE = 160
BATCH_SIZE = 32
NUM_CLASSES = 2
CLASS_MODE = 'categorical'

image_gen_train = ImageDataGenerator(rescale=1./255)
train_data_gen = image_gen_train.flow_from_directory(
    batch_size=BATCH_SIZE, 
    directory=LEVEL_TRAIN_DIR, 
    shuffle=True, 
    target_size=(TARGET_SHAPE,TARGET_SHAPE),
    class_mode=CLASS_MODE)


# Validation data should not be augmented!
image_gen_val = ImageDataGenerator(rescale=1./255)
val_data_gen = image_gen_val.flow_from_directory(
    batch_size=BATCH_SIZE, 
    directory=LEVEL_VAL_DIR,                     
    target_size=(TARGET_SHAPE, TARGET_SHAPE),
    class_mode=CLASS_MODE)

# Test data should not be augmented!
image_gen_test = ImageDataGenerator(rescale=1./255)
test_data_gen = image_gen_test.flow_from_directory(
    batch_size=BATCH_SIZE, 
    directory=LEVEL_TEST_DIR, 
    target_size=(TARGET_SHAPE, TARGET_SHAPE),
    class_mode=CLASS_MODE)
# Out:
# Found 205 images belonging to 2 classes.
# Found 63 images belonging to 2 classes.
# Found 33 images belonging to 2 classes.

# %% [markdown]
# ### Sample Training Data after Data Augmentation

# %%
sample_training_images, sample_training_labels = next(train_data_gen)

plotImages(sample_training_images[:5])

# %% [markdown]
# ### Sample Validation data

# %%
sample_val_images, sample_val_labels = next(val_data_gen)

plotImages(sample_val_images[:5])

# %% [markdown]
# ### Sample Test Data

# %%
sample_test_images, sample_test_labels = next(test_data_gen)

plotImages(sample_test_images[:5])

# %% [markdown]
# ### Train with Mobile Net

# %%
mobile_net = applications.MobileNet(weights='imagenet',include_top=False, input_shape=(TARGET_SHAPE, TARGET_SHAPE, 3))

conv_base = mobile_net
conv_base.trainable = False

model_mobile = getModel(conv_base)

# %%
model_mobile.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenet_1.00_160 (Model)   (None, 5, 5, 1024)        3228864
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 25600)             0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 25600)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 216)               5529816
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 434
# =================================================================
# Total params: 8,759,114
# Trainable params: 5,530,250
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %%
# %%time

EPOCHS = 20

history_mobile = trainModel(model_mobile, total_train, total_val, 
           train_data_gen, val_data_gen, EPOCHS)
# Out:
# Epoch 1/20
# 7/7 - 20s - loss: 5.8107 - acc: 0.5366 - val_loss: 10.4963 - val_acc: 0.3492
# Epoch 2/20
# 7/7 - 15s - loss: 4.2447 - acc: 0.6878 - val_loss: 2.0269 - val_acc: 0.7619
# Epoch 3/20
# 7/7 - 15s - loss: 3.0637 - acc: 0.7707 - val_loss: 5.2174 - val_acc: 0.5238
# Epoch 4/20
# 7/7 - 13s - loss: 2.4088 - acc: 0.8341 - val_loss: 2.8326 - val_acc: 0.7143
# Epoch 5/20
# 7/7 - 13s - loss: 2.2314 - acc: 0.8293 - val_loss: 3.8263 - val_acc: 0.6508
# Epoch 6/20
# 7/7 - 13s - loss: 1.7390 - acc: 0.8634 - val_loss: 4.4898 - val_acc: 0.5714
# Epoch 7/20
# 7/7 - 14s - loss: 1.5769 - acc: 0.8732 - val_loss: 5.1326 - val_acc: 0.5079
# Epoch 8/20
# 7/7 - 16s - loss: 1.7269 - acc: 0.8780 - val_loss: 3.5412 - val_acc: 0.6825
# Epoch 9/20
# 7/7 - 13s - loss: 1.0683 - acc: 0.9220 - val_loss: 3.6751 - val_acc: 0.6508
# Epoch 10/20
# 7/7 - 14s - loss: 0.9473 - acc: 0.9366 - val_loss: 3.5010 - val_acc: 0.6190
# Epoch 11/20
# 7/7 - 14s - loss: 0.7354 - acc: 0.9463 - val_loss: 2.9680 - val_acc: 0.6508
# Epoch 12/20
# 7/7 - 14s - loss: 0.8700 - acc: 0.9366 - val_loss: 3.6356 - val_acc: 0.6667
# Epoch 13/20
# 7/7 - 14s - loss: 0.8754 - acc: 0.9415 - val_loss: 3.2052 - val_acc: 0.6825
# Epoch 14/20
# 7/7 - 15s - loss: 0.6808 - acc: 0.9512 - val_loss: 2.8974 - val_acc: 0.6508
# Epoch 15/20
# 7/7 - 14s - loss: 0.6847 - acc: 0.9463 - val_loss: 3.9180 - val_acc: 0.6825
# Epoch 16/20
# 7/7 - 14s - loss: 0.7853 - acc: 0.9415 - val_loss: 3.1062 - val_acc: 0.6825
# Epoch 17/20
# 7/7 - 14s - loss: 0.8077 - acc: 0.9415 - val_loss: 2.9384 - val_acc: 0.7302
# Epoch 18/20
# 7/7 - 15s - loss: 0.7539 - acc: 0.9512 - val_loss: 3.1326 - val_acc: 0.7143
# Epoch 19/20
# 7/7 - 14s - loss: 0.5851 - acc: 0.9610 - val_loss: 3.1612 - val_acc: 0.6825
# Epoch 20/20
# 7/7 - 15s - loss: 0.7736 - acc: 0.9512 - val_loss: 3.4058 - val_acc: 0.6984
# CPU times: user 9min 21s, sys: 6.66 s, total: 9min 27s
# Wall time: 4min 50s

# %%
plotTrainVal(history_mobile, EPOCHS)

# %%
predictions_mobile = model_mobile.predict(sample_test_images)
y_pred_1= np.argmax(predictions_mobile, axis=1)

confusion_matrix_mobile = confusion_matrix(np.argmax(sample_test_labels, axis=1), y_pred_1)
plot_confusion_matrix(confusion_matrix_mobile, CLASS_NAMES)
# Out:
# Confusion matrix, without normalization
# [[25  2]
#  [ 5  0]]

# %% [markdown]
# ### Saving Model to GCP

# %%
from google.colab import auth
auth.authenticate_user()

# %%
from google.cloud import storage

CLIENT = storage.Client(project=GCP_PROJECT_ID)
BUCKET_ = CLIENT.bucket(GCP_BUCKET_NAME)

def save_model_to_gcp(model, model_name):
   
  
  # Save Keras ModelCheckpoints locally
  model.save(os.path.join("/tmp", model_name))


  # Copy over to Google Cloud Storage
  BLOB_DESTINATION = os.path.join("model", model_name)
  blob = BUCKET_.blob(BLOB_DESTINATION)
  blob.upload_from_filename(os.path.join("/tmp", model_name))
  
  # gcs url to uploaded matplotlib image
  url = blob.public_url
  
  print("Model saved at {}".format(url))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0512 19:18:55.907488 140130952456064 _default.py:280] No project ID could be determined. Consider running `gcloud config set project` or setting the GOOGLE_CLOUD_PROJECT environment variable

# %%
model_name = "level{}_window_{}.h5".format(LEVEL, WINDOW)
save_model_to_gcp(model_mobile, model_name)
# Out:
# Model saved at https://storage.googleapis.com/vaa2114_dl_2019/model/level5_window_400.h5

# %% [markdown]
# ### Load and Test Model

# %%
LOCAL_MODEL_DIR = "/tmp/model"

# %%
# !gsutil -m cp gs://{GCP_BUCKET_NAME}/model/{model_name} {LOCAL_MODEL_DIR}/{model_name}
# Out:
# Copying gs://vaa2114_dl_2019/model/level5_window_400.h5...
# - [1/1 files][ 75.8 MiB/ 75.8 MiB] 100% Done
# Operation completed over 1 objects/75.8 MiB.

# %%
loaded_model = load_model("{}/{}".format(LOCAL_MODEL_DIR, model_name))

# %%
predictions_new = loaded_model.predict(sample_test_images)
y_preds= np.argmax(predictions_new, axis=1)

confusion_matrix_new = confusion_matrix(np.argmax(sample_test_labels, axis=1), y_preds)
plot_confusion_matrix(confusion_matrix_new, CLASS_NAMES)
# Out:
# Confusion matrix, without normalization
# [[25  2]
#  [ 5  0]]
